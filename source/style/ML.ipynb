# %%
import os
import joblib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier  # 분류분석
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score, fbeta_score
from sklearn.metrics import adjusted_rand_score, homogeneity_score, completeness_score, v_measure_score, mutual_info_score
from sklearn.neural_network import MLPClassifier
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, VotingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %% [markdown]
# # data load

# %%
VGG_vectors = np.load('../../data/VGG_vectors.npy')
VGG_vectors.shape
# Out:
# (80158, 512)

# %%
painting = pd.read_csv('painting.csv')
painting.head()
# Out:
#                                                 file  \
# 0  Realism/vincent-van-gogh_pine-trees-in-the-fen...
# 1  Baroque/rembrandt_the-angel-appearing-to-the-s...
# 2  Post_Impressionism/paul-cezanne_portrait-of-th...
# 3  Impressionism/pierre-auguste-renoir_young-girl...
# 4       Romanticism/ivan-aivazovsky_morning-1851.jpg
#
#                                        title                 artist  \
# 0                 pine-trees-in-the-fen-1884       vincent-van-gogh
# 1  the-angel-appearing-to-the-shepherds-1634              rembrandt
# 2               portrait-of-the-artist-s-son           paul-cezanne
# 3         young-girl-seated-in-a-meadow-1916  pierre-auguste-renoir
# 4                               morning-1851        ivan-aivazovsky
#
#                 genre               style
# 0           landscape             Realism
# 1  religious painting             Baroque
# 2            portrait  Post_Impressionism
# 3      genre painting       Impressionism
# 4              marina         Romanticism

# %%
X = VGG_vectors
y = painting['style']

# %%
# 독립변수 스케일 조정
smote = SMOTE(sampling_strategy='auto', random_state=42)
X, y = smote.fit_resample(X, y)

# %%
undersample = NearMiss(version=1)
X_sampled, y_sampled = undersample.fit_resample(X, y)

# %%
pd.Series(y_sampled).value_counts()
# Out:
# Abstract_Expressionism        12683
# Minimalism                    12683
# Synthetic_Cubism              12683
# Symbolism                     12683
# Romanticism                   12683
# Rococo                        12683
# Realism                       12683
# Post_Impressionism            12683
# Pop_Art                       12683
# Pointillism                   12683
# Northern_Renaissance          12683
# New_Realism                   12683
# Naive_Art_Primitivism         12683
# Mannerism_Late_Renaissance    12683
# Action_painting               12683
# Impressionism                 12683
# High_Renaissance              12683
# Fauvism                       12683
# Expressionism                 12683
# Early_Renaissance             12683
# Cubism                        12683
# Contemporary_Realism          12683
# Color_Field_Painting          12683
# Baroque                       12683
# Art_Nouveau_Modern            12683
# Analytical_Cubism             12683
# Ukiyo_e                       12683
# Name: style, dtype: int64

# %%
train_X, test_X, train_y, test_y = train_test_split(X_sampled, y_sampled, 
                                                    test_size=0.3, 
                                                    shuffle=True,  # 분할 전 데이터 섞기
                                                    stratify=y_sampled     # 층화추출
                                                   )
train_X.shape, test_X.shape, train_y.shape, test_y.shape
# Out:
# ((239708, 512), (102733, 512), (239708,), (102733,))

# %% [markdown]
# # 분류분석

# %% [markdown]
# ## DecisionTreeClassifier

# %%
# 의사결정나무를 구현한 DecisionTreeClassifier를 통한 모형
dt_model = DecisionTreeClassifier(random_state=1)
dt_model = dt_model.fit(train_X, train_y)  # 머신러닝에서는 fit시 독립변수에 array
dt_model
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
dt_model.score(test_X, test_y)
# Out:
# 0.624015652224699

# %%
dt_pred_y = dt_model.predict(test_X)
pd.crosstab(test_y, dt_pred_y)  # 실제값, 예측값
# Out:
# col_0                       Abstract_Expressionism  Action_painting  \
# style
# Abstract_Expressionism                        2062               23
# Action_painting                                 24             3712
# Analytical_Cubism                                3                0
# Art_Nouveau_Modern                             124               13
# Baroque                                         19                4
# Color_Field_Painting                           174                3
# Contemporary_Realism                            40                3
# Cubism                                         117               14
# Early_Renaissance                               25                7
# Expressionism                                  155               10
# Fauvism                                        105                4
# High_Renaissance                                24                0
# Impressionism                                   87               16
# Mannerism_Late_Renaissance                      12                0
# Minimalism                                     113                2
# Naive_Art_Primitivism                          108                9
# New_Realism                                     15                1
# Northern_Renaissance                            41                3
# Pointillism                                     16                1
# Pop_Art                                        156                4
# Post_Impressionism                             109               11
# Realism                                         71                9
# Rococo                                          11                3
# Romanticism                                     45                4
# Symbolism                                      103                8
# Synthetic_Cubism                                 5                0
# Ukiyo_e                                         72                4
#
# col_0                       Analytical_Cubism  Art_Nouveau_Modern  Baroque  \
# style
# Abstract_Expressionism                      7                  89       30
# Action_painting                             1                   5        0
# Analytical_Cubism                        3737                   2        1
# Art_Nouveau_Modern                          5                1599       83
# Baroque                                     0                  63     1819
# Color_Field_Painting                        1                  25        5
# Contemporary_Realism                        2                  35       28
# Cubism                                     25                  90       21
# Early_Renaissance                           8                  58       76
# Expressionism                              18                 182      101
# Fauvism                                     6                  69        7
# High_Renaissance                            3                  55      102
# Impressionism                               9                 130      137
# Mannerism_Late_Renaissance                  3                  38      148
# Minimalism                                  1                  32       17
# Naive_Art_Primitivism                       4                 115       59
# New_Realism                                 1                  20       24
# Northern_Renaissance                        3                  86      126
# Pointillism                                 0                  33       13
# Pop_Art                                     4                 110       18
# Post_Impressionism                          8                 186       81
# Realism                                     2                 154      238
# Rococo                                      2                  42      222
# Romanticism                                 6                 111      233
# Symbolism                                   6                 185      110
# Synthetic_Cubism                            0                   7        5
# Ukiyo_e                                     7                 115       12
#
# col_0                       Color_Field_Painting  Contemporary_Realism  \
# style
# Abstract_Expressionism                       171                    39
# Action_painting                                2                     4
# Analytical_Cubism                              0                     2
# Art_Nouveau_Modern                            39                    44
# Baroque                                        6                    27
# Color_Field_Painting                        3057                    21
# Contemporary_Realism                          16                  3146
# Cubism                                        50                    27
# Early_Renaissance                              4                    23
# Expressionism                                 42                    69
# Fauvism                                       33                    24
# High_Renaissance                               3                    21
# Impressionism                                 16                   102
# Mannerism_Late_Renaissance                     3                    18
# Minimalism                                   217                    14
# Naive_Art_Primitivism                         19                    52
# New_Realism                                    1                    20
# Northern_Renaissance                           8                    34
# Pointillism                                    4                    21
# Pop_Art                                       80                    21
# Post_Impressionism                            24                    59
# Realism                                       12                    89
# Rococo                                         5                    20
# Romanticism                                   12                    61
# Symbolism                                     27                    64
# Synthetic_Cubism                               1                     4
# Ukiyo_e                                        4                    17
#
# col_0                       Cubism  Early_Renaissance  Expressionism  ...  \
# style                                                                 ...
# Abstract_Expressionism         105                 30            137  ...
# Action_painting                  1                  2              6  ...
# Analytical_Cubism                9                  2             11  ...
# Art_Nouveau_Modern             112                 84            198  ...
# Baroque                         21                 63            110  ...
# Color_Field_Painting            27                  6             24  ...
# Contemporary_Realism            33                 15             26  ...
# Cubism                        2253                 43            209  ...
# Early_Renaissance               46               2614             78  ...
# Expressionism                  222                 77           1015  ...
# Fauvism                        102                 14            162  ...
# High_Renaissance                18                102             87  ...
# Impressionism                   69                 74            167  ...
# Mannerism_Late_Renaissance      26                 66             52  ...
# Minimalism                      32                  8             19  ...
# Naive_Art_Primitivism          102                 49            170  ...
# New_Realism                     11                 23             25  ...
# Northern_Renaissance            46                123            106  ...
# Pointillism                     21                 11             19  ...
# Pop_Art                        126                 18             92  ...
# Post_Impressionism             107                 71            214  ...
# Realism                         50                100            198  ...
# Rococo                          19                 57             68  ...
# Romanticism                     40                 80            139  ...
# Symbolism                       73                 87            198  ...
# Synthetic_Cubism                66                  3              7  ...
# Ukiyo_e                         54                 24             64  ...
#
# col_0                       Northern_Renaissance  Pointillism  Pop_Art  \
# style
# Abstract_Expressionism                        41           31      157
# Action_painting                                4            1        4
# Analytical_Cubism                              2            0        0
# Art_Nouveau_Modern                           103           55      106
# Baroque                                      123           23       28
# Color_Field_Painting                          12            9       74
# Contemporary_Realism                          27           15       34
# Cubism                                        44           18      116
# Early_Renaissance                            137           22       14
# Expressionism                                134           49      116
# Fauvism                                       30           51       76
# High_Renaissance                             134           15       11
# Impressionism                                 94          129       29
# Mannerism_Late_Renaissance                   107            6       11
# Minimalism                                     8            2       78
# Naive_Art_Primitivism                         61           50      112
# New_Realism                                   34            8       10
# Northern_Renaissance                        2149           19       28
# Pointillism                                   17         3275        9
# Pop_Art                                       24           21     2573
# Post_Impressionism                           121          122       52
# Realism                                      150           69       40
# Rococo                                        79           17       16
# Romanticism                                  140           32       43
# Symbolism                                     96           65       51
# Synthetic_Cubism                               4            4       11
# Ukiyo_e                                       31           24       62
#
# col_0                       Post_Impressionism  Realism  Rococo  Romanticism  \
# style
# Abstract_Expressionism                      98       60      20           67
# Action_painting                              7        1       1            1
# Analytical_Cubism                            8        2       0            4
# Art_Nouveau_Modern                         140      132      62          110
# Baroque                                     61      220     291          222
# Color_Field_Painting                        16       22       1           10
# Contemporary_Realism                        51       41      15           37
# Cubism                                     100       37      13           34
# Early_Renaissance                           68       54      60           62
# Expressionism                              184      158      64          151
# Fauvism                                    103       23       9           18
# High_Renaissance                            58       65      80           73
# Impressionism                              376      510     114          280
# Mannerism_Late_Renaissance                  38       69      87           89
# Minimalism                                  17       14       1           15
# Naive_Art_Primitivism                      150       67      28           74
# New_Realism                                 41       47      13           30
# Northern_Renaissance                       107      116      84          115
# Pointillism                                 81       27      10           22
# Pop_Art                                     67       20      13           27
# Post_Impressionism                        1113      230      67          134
# Realism                                    234      791     167          352
# Rococo                                      48      141    2443          207
# Romanticism                                149      332     215         1283
# Symbolism                                  190      190      75          166
# Synthetic_Cubism                             8        3       5            2
# Ukiyo_e                                     54       25      10           27
#
# col_0                       Symbolism  Synthetic_Cubism  Ukiyo_e
# style
# Abstract_Expressionism            100                16       52
# Action_painting                     6                 0        2
# Analytical_Cubism                   6                 5        4
# Art_Nouveau_Modern                169                10      113
# Baroque                           102                 2       15
# Color_Field_Painting               29                 5       11
# Contemporary_Realism               44                 3       15
# Cubism                             70                71       64
# Early_Renaissance                  73                 3       24
# Expressionism                     184                21       98
# Fauvism                            52                13       34
# High_Renaissance                   66                 3       17
# Impressionism                     176                 6       32
# Mannerism_Late_Renaissance         51                 3       13
# Minimalism                         32                 6        6
# Naive_Art_Primitivism              98                11       75
# New_Realism                        36                 3       11
# Northern_Renaissance               80                 3       40
# Pointillism                        34                 0       14
# Pop_Art                            45                12       54
# Post_Impressionism                191                11       66
# Realism                           177                 5       36
# Rococo                             58                 2        8
# Romanticism                       176                 8       29
# Symbolism                        1521                 5       47
# Synthetic_Cubism                    2              3640        2
# Ukiyo_e                            48                16     2959
#
# [27 rows x 27 columns]

# %%
# y_test는 실제 정답 (원-핫 인코딩된 경우 argmax로 변환)
y_test_labels = test_y
y_pred_labels = dt_pred_y  # 모델 예측값도 동일하게 변환

# ✅ 상세한 성능 지표 출력
print("🔹 Classification Report:")
print(classification_report(y_test_labels, y_pred_labels, digits=4))

# ✅ 개별 지표 계산 (매크로 평균 사용)
precision = precision_score(y_test_labels, y_pred_labels, average='macro')
recall = recall_score(y_test_labels, y_pred_labels, average='macro')
f1 = f1_score(y_test_labels, y_pred_labels, average='macro')

print(f"🎯 Precision: {precision:.4f}")
print(f"🔄 Recall: {recall:.4f}")
print(f"🔥 F1-score: {f1:.4f}")
# Out:
# 🔹 Classification Report:
#                             precision    recall  f1-score   support
#
#     Abstract_Expressionism     0.5375    0.5419    0.5397      3805
#            Action_painting     0.9597    0.9756    0.9675      3805
#          Analytical_Cubism     0.9659    0.9821    0.9739      3805
#         Art_Nouveau_Modern     0.4398    0.4202    0.4298      3805
#                    Baroque     0.4895    0.4781    0.4837      3805
#       Color_Field_Painting     0.7928    0.8034    0.7981      3805
#       Contemporary_Realism     0.7781    0.8268    0.8017      3805
#                     Cubism     0.5943    0.5921    0.5932      3805
#          Early_Renaissance     0.6797    0.6870    0.6833      3805
#              Expressionism     0.2819    0.2668    0.2741      3805
#                    Fauvism     0.6853    0.7057    0.6953      3805
#           High_Renaissance     0.6618    0.6857    0.6736      3805
#              Impressionism     0.2487    0.2229    0.2351      3805
# Mannerism_Late_Renaissance     0.6880    0.7224    0.7048      3804
#                 Minimalism     0.8169    0.8163    0.8166      3805
#      Naive_Art_Primitivism     0.5331    0.5351    0.5341      3805
#                New_Realism     0.8258    0.8710    0.8478      3805
#       Northern_Renaissance     0.5502    0.5648    0.5574      3805
#                Pointillism     0.7926    0.8607    0.8252      3805
#                    Pop_Art     0.6664    0.6762    0.6713      3805
#         Post_Impressionism     0.3120    0.2926    0.3020      3804
#                    Realism     0.2329    0.2079    0.2197      3805
#                     Rococo     0.6188    0.6420    0.6302      3805
#                Romanticism     0.3552    0.3372    0.3460      3805
#                  Symbolism     0.4195    0.3997    0.4094      3805
#           Synthetic_Cubism     0.9374    0.9566    0.9469      3805
#                    Ukiyo_e     0.7704    0.7777    0.7740      3805
#
#                   accuracy                         0.6240    102733
#                  macro avg     0.6161    0.6240    0.6198    102733
#               weighted avg     0.6161    0.6240    0.6198    102733
#
# 🎯 Precision: 0.6161
# 🔄 Recall: 0.6240
# 🔥 F1-score: 0.6198

# %%
# fbeta score의 beta=1 : f1 score
# fbeta score의 2>=beta>1 : recall의 가중치가 높게 조정된 f1 score
# fbeta score의 0<=beta<1 : precision의 가중치가 높게 조정된 f1 score
print(fbeta_score(test_y, dt_pred_y, beta=0.5, average='macro'))
print(fbeta_score(test_y, dt_pred_y, beta=1, average='macro'))
print(fbeta_score(test_y, dt_pred_y, beta=2, average='macro'))
# Out:
# 0.6175044067161766
# 0.6197924170995668
# 0.6222636703382227

# %% [markdown]
# ## MLPClassifier

# %%
# 다중신경망 모형
mlp_model = MLPClassifier(hidden_layer_sizes=(38, 64, 32), max_iter=500, random_state=1)
mlp_model = mlp_model.fit(train_X, train_y)
mlp_model
# Out:
# MLPClassifier(hidden_layer_sizes=(38, 64, 32), max_iter=500, random_state=1)

# %%
mlp_model.score(test_X, test_y)
# Out:
# 0.7234189598279034

# %%
mlp_pred_y = mlp_model.predict(test_X)
mlp_result = pd.crosstab(test_y, mlp_pred_y)
mlp_result
# Out:
# col_0                       Abstract_Expressionism  Action_painting  \
# style
# Abstract_Expressionism                        2656               17
# Action_painting                                 10             3791
# Analytical_Cubism                                3                0
# Art_Nouveau_Modern                              84                2
# Baroque                                         11                0
# Color_Field_Painting                           217                5
# Contemporary_Realism                            17                0
# Cubism                                         109                0
# Early_Renaissance                                1                0
# Expressionism                                  190                5
# Fauvism                                         32                7
# High_Renaissance                                 9                1
# Impressionism                                   57                0
# Mannerism_Late_Renaissance                       7                0
# Minimalism                                      83                1
# Naive_Art_Primitivism                           97                0
# New_Realism                                      2                0
# Northern_Renaissance                            12                2
# Pointillism                                      6                0
# Pop_Art                                        123                1
# Post_Impressionism                              73                2
# Realism                                         49                1
# Rococo                                           1                0
# Romanticism                                     10                1
# Symbolism                                      108                0
# Synthetic_Cubism                                 0                0
# Ukiyo_e                                          3                1
#
# col_0                       Analytical_Cubism  Art_Nouveau_Modern  Baroque  \
# style
# Abstract_Expressionism                      1                  55        6
# Action_painting                             0                   2        0
# Analytical_Cubism                        3783                   0        0
# Art_Nouveau_Modern                          0                1635       39
# Baroque                                     0                  32     2073
# Color_Field_Painting                        0                   3        3
# Contemporary_Realism                        0                   8        2
# Cubism                                      6                  52       12
# Early_Renaissance                           0                  61       43
# Expressionism                               3                 238       71
# Fauvism                                     1                  21        1
# High_Renaissance                            1                  10      160
# Impressionism                               1                  91       75
# Mannerism_Late_Renaissance                  0                   7      225
# Minimalism                                  0                   1        0
# Naive_Art_Primitivism                       0                 138       17
# New_Realism                                 0                   7       13
# Northern_Renaissance                        0                  95      192
# Pointillism                                 0                  10        0
# Pop_Art                                     0                  36        0
# Post_Impressionism                          2                 156       33
# Realism                                     0                 148      305
# Rococo                                      0                  12      243
# Romanticism                                 0                 100      410
# Symbolism                                   0                 260      110
# Synthetic_Cubism                            0                   0        0
# Ukiyo_e                                     0                  61        4
#
# col_0                       Color_Field_Painting  Contemporary_Realism  \
# style
# Abstract_Expressionism                       118                    10
# Action_painting                                0                     0
# Analytical_Cubism                              0                     0
# Art_Nouveau_Modern                             4                    24
# Baroque                                        3                     4
# Color_Field_Painting                        3363                     8
# Contemporary_Realism                           4                  3612
# Cubism                                        14                     1
# Early_Renaissance                              0                     0
# Expressionism                                  7                    25
# Fauvism                                        1                     4
# High_Renaissance                               0                     4
# Impressionism                                  4                    37
# Mannerism_Late_Renaissance                     0                     6
# Minimalism                                   129                     3
# Naive_Art_Primitivism                          4                    13
# New_Realism                                    1                     2
# Northern_Renaissance                           4                     2
# Pointillism                                    0                     1
# Pop_Art                                       31                    10
# Post_Impressionism                             9                    19
# Realism                                        0                    35
# Rococo                                         0                     4
# Romanticism                                    0                    21
# Symbolism                                      3                    18
# Synthetic_Cubism                               0                     0
# Ukiyo_e                                        0                     0
#
# col_0                       Cubism  Early_Renaissance  Expressionism  ...  \
# style                                                                 ...
# Abstract_Expressionism         135                 13            150  ...
# Action_painting                  0                  0              1  ...
# Analytical_Cubism               10                  8              1  ...
# Art_Nouveau_Modern             102                 61            295  ...
# Baroque                          6                 60             46  ...
# Color_Field_Painting             6                  2              5  ...
# Contemporary_Realism             5                  1             14  ...
# Cubism                        2835                  3            269  ...
# Early_Renaissance                6               3321             20  ...
# Expressionism                  363                 48           1034  ...
# Fauvism                         77                  3            114  ...
# High_Renaissance                 3                161             13  ...
# Impressionism                   43                 30            129  ...
# Mannerism_Late_Renaissance       3                 60             17  ...
# Minimalism                       5                  2              3  ...
# Naive_Art_Primitivism           90                 16            212  ...
# New_Realism                      3                  6             14  ...
# Northern_Renaissance            13                139             68  ...
# Pointillism                      1                  1              5  ...
# Pop_Art                         54                  2             45  ...
# Post_Impressionism             131                 39            350  ...
# Realism                         19                 51            154  ...
# Rococo                           2                 23              7  ...
# Romanticism                      9                 61             74  ...
# Symbolism                       65                 76            270  ...
# Synthetic_Cubism                18                  0              0  ...
# Ukiyo_e                          4                  6             23  ...
#
# col_0                       Northern_Renaissance  Pointillism  Pop_Art  \
# style
# Abstract_Expressionism                         1            2      185
# Action_painting                                0            0        0
# Analytical_Cubism                              0            0        0
# Art_Nouveau_Modern                            85           20      117
# Baroque                                      111            2        8
# Color_Field_Painting                           0            3       36
# Contemporary_Realism                           1            0       27
# Cubism                                         6            8      108
# Early_Renaissance                             92            1        3
# Expressionism                                 60           27      114
# Fauvism                                        2           18       58
# High_Renaissance                             128            3        4
# Impressionism                                 30           63       17
# Mannerism_Late_Renaissance                    76            0        5
# Minimalism                                     0            0       55
# Naive_Art_Primitivism                         32            8      152
# New_Realism                                    3            1        2
# Northern_Renaissance                        2420            3        6
# Pointillism                                    0         3699        7
# Pop_Art                                        5            8     3337
# Post_Impressionism                            63           63       39
# Realism                                       77           16       29
# Rococo                                        34            0        2
# Romanticism                                   96            7       11
# Symbolism                                     66           15       39
# Synthetic_Cubism                               0            0        0
# Ukiyo_e                                        6            4       25
#
# col_0                       Post_Impressionism  Realism  Rococo  Romanticism  \
# style
# Abstract_Expressionism                      29       15       2            1
# Action_painting                              0        0       0            0
# Analytical_Cubism                            0        0       0            0
# Art_Nouveau_Modern                         221       86      48           52
# Baroque                                     24      152     661          190
# Color_Field_Painting                         2        0       0            0
# Contemporary_Realism                         7        8       0            8
# Cubism                                     101        3       2            1
# Early_Renaissance                           17        7      13           13
# Expressionism                              358      137      29           34
# Fauvism                                     78        0       0            0
# High_Renaissance                            23       28      67           30
# Impressionism                              755      455      76           89
# Mannerism_Late_Renaissance                   1       12     127           12
# Minimalism                                   3        2       0            5
# Naive_Art_Primitivism                      185       35       9           20
# New_Realism                                 39        9      12            6
# Northern_Renaissance                        86       96      77           94
# Pointillism                                 28        2       0            0
# Pop_Art                                     10        5       0            0
# Post_Impressionism                        1407      177      13           37
# Realism                                    290     1133     219          307
# Rococo                                       2       42    3194          103
# Romanticism                                 94      479     536         1219
# Symbolism                                  192      143     109           97
# Synthetic_Cubism                             0        0       0            0
# Ukiyo_e                                     11        3       0            0
#
# col_0                       Symbolism  Synthetic_Cubism  Ukiyo_e
# style
# Abstract_Expressionism            126                 5       24
# Action_painting                     0                 0        1
# Analytical_Cubism                   0                 0        0
# Art_Nouveau_Modern                371                 0      119
# Baroque                            72                 0        5
# Color_Field_Painting               13                 0        1
# Contemporary_Realism               41                 0        6
# Cubism                             25                42        7
# Early_Renaissance                  35                 0        3
# Expressionism                     340                 5       35
# Fauvism                            17                 0        1
# High_Renaissance                   10                 1        2
# Impressionism                     213                 1       12
# Mannerism_Late_Renaissance         26                 0        0
# Minimalism                          3                 0        1
# Naive_Art_Primitivism              79                 1       36
# New_Realism                        12                 0        3
# Northern_Renaissance               68                 0       21
# Pointillism                         0                 0        0
# Pop_Art                            19                 0       24
# Post_Impressionism                242                 3       38
# Realism                           227                 2       22
# Rococo                             40                 0        2
# Romanticism                       238                 0       12
# Symbolism                        1794                 4       36
# Synthetic_Cubism                    0              3785        1
# Ukiyo_e                            14                 0     3604
#
# [27 rows x 27 columns]

# %%
# y_test는 실제 정답 (원-핫 인코딩된 경우 argmax로 변환)
y_test_labels = test_y
y_pred_labels = mlp_pred_y  # 모델 예측값도 동일하게 변환

# ✅ 상세한 성능 지표 출력
print("🔹 Classification Report:")
print(classification_report(y_test_labels, y_pred_labels, digits=4))

# ✅ 개별 지표 계산 (매크로 평균 사용)
precision = precision_score(y_test_labels, y_pred_labels, average='macro')
recall = recall_score(y_test_labels, y_pred_labels, average='macro')
f1 = f1_score(y_test_labels, y_pred_labels, average='macro')

print(f"🎯 Precision: {precision:.4f}")
print(f"🔄 Recall: {recall:.4f}")
print(f"🔥 F1-score: {f1:.4f}")
# Out:
# 🔹 Classification Report:
#                             precision    recall  f1-score   support
#
#     Abstract_Expressionism     0.6690    0.6980    0.6832      3805
#            Action_painting     0.9880    0.9963    0.9921      3805
#          Analytical_Cubism     0.9961    0.9942    0.9951      3805
#         Art_Nouveau_Modern     0.5048    0.4297    0.4642      3805
#                    Baroque     0.5135    0.5448    0.5287      3805
#       Color_Field_Painting     0.9092    0.8838    0.8963      3805
#       Contemporary_Realism     0.9350    0.9493    0.9421      3805
#                     Cubism     0.7073    0.7451    0.7257      3805
#          Early_Renaissance     0.7920    0.8728    0.8305      3805
#              Expressionism     0.3102    0.2717    0.2897      3805
#                    Fauvism     0.8202    0.8778    0.8480      3805
#           High_Renaissance     0.7903    0.7982    0.7942      3805
#              Impressionism     0.4596    0.3782    0.4149      3805
# Mannerism_Late_Renaissance     0.7972    0.8247    0.8107      3804
#                 Minimalism     0.9120    0.9204    0.9162      3805
#      Naive_Art_Primitivism     0.6341    0.6662    0.6498      3805
#                New_Realism     0.9583    0.9551    0.9567      3805
#       Northern_Renaissance     0.7130    0.6360    0.6723      3805
#                Pointillism     0.9315    0.9721    0.9514      3805
#                    Pop_Art     0.7608    0.8770    0.8148      3805
#         Post_Impressionism     0.3550    0.3699    0.3623      3804
#                    Realism     0.3741    0.2978    0.3316      3805
#                     Rococo     0.6149    0.8394    0.7099      3805
#                Romanticism     0.5259    0.3204    0.3982      3805
#                  Symbolism     0.4457    0.4715    0.4582      3805
#           Synthetic_Cubism     0.9834    0.9947    0.9890      3805
#                    Ukiyo_e     0.8974    0.9472    0.9216      3805
#
#                   accuracy                         0.7234    102733
#                  macro avg     0.7148    0.7234    0.7166    102733
#               weighted avg     0.7148    0.7234    0.7166    102733
#
# 🎯 Precision: 0.7148
# 🔄 Recall: 0.7234
# 🔥 F1-score: 0.7166

# %%
# fbeta score의 beta=1 : f1 score
# fbeta score의 2>=beta>1 : recall의 가중치가 높게 조정된 f1 score
# fbeta score의 0<=beta<1 : precision의 가중치가 높게 조정된 f1 score
print(fbeta_score(test_y, mlp_pred_y, beta=0.5, average='macro'))
print(fbeta_score(test_y, mlp_pred_y, beta=1, average='macro'))
print(fbeta_score(test_y, mlp_pred_y, beta=2, average='macro'))
# Out:
# 0.7148040872596299
# 0.716573342839279
# 0.7201190376098922

# %% [markdown]
# # 군집분석

# %%
os.environ['OMP_NUM_THREADS'] = '1'

# %%
# 그래프 저장 시 해상도 높게
# %config InlineBackend.figure_format = 'retina'

# 한글설정
# plt.rc('font', family='Malgun Gothic')  # 윈도우즈
# plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rc('font', family='AppleGothic') # Mac 운영체제
plt.rc('axes', unicode_minus=False)  # 축의 -(마이너스) 깨짐 방지

# %% [markdown]
# ## KMeans 클러스터링

# %%
len(set(y))
# Out:
# 27

# %%
kmeans_model = KMeans(n_clusters=len(set(y)),  # 클러스터 갯수:2개의 그룹으로 나눔
               init='random', # random(중심초기점이 random), k-means++(멀리 떨어진 초기점)
               n_init=5,
               max_iter=300)  # 300번 중심점 이동
kmeans_model.fit(X)
# Out:
# KMeans(init='random', n_clusters=27, n_init=5)

# %%
kmeans_model.cluster_centers_  # 최종 두 클러스터의 중심점
# Out:
# array([[ 1.6422336 ,  0.40981466,  4.805969  , ...,  0.39349532,
#          1.0919907 ,  1.1235657 ],
#        [ 1.5721786 ,  0.5540645 ,  0.73407924, ...,  1.1769555 ,
#          3.2021556 ,  2.0652304 ],
#        [ 2.6720524 ,  0.8716313 ,  3.103767  , ...,  1.3163974 ,
#          2.0373752 ,  3.6216328 ],
#        ...,
#        [ 0.891065  ,  0.31821203,  0.55722046, ...,  0.35978925,
#          0.76995975,  0.46872425],
#        [ 5.6154795 ,  1.6334686 ,  1.978476  , ...,  2.08456   ,
#          3.448163  ,  6.4242907 ],
#        [ 5.0331397 ,  2.4982724 ,  6.4244356 , ..., 11.2992935 ,
#          1.981703  , 17.796188  ]], dtype=float32)

# %%
len(kmeans_model.cluster_centers_)
# Out:
# 27

# %%
pred = kmeans_model.predict(X)
print(' 예 측 값 : ', pred)
print('modelLabel: ', kmeans_model.labels_)
print(' 실제 y값 : ', y)
# Out:
#  예 측 값 :  [19  0 20 ...  5 25  6]
# modelLabel:  [19  0 20 ...  5 25  6]
#  실제 y값 :  0                    Realism
# 1                    Baroque
# 2         Post_Impressionism
# 3              Impressionism
# 4                Romanticism
#                  ...
# 342436               Ukiyo_e
# 342437               Ukiyo_e
# 342438               Ukiyo_e
# 342439               Ukiyo_e
# 342440               Ukiyo_e
# Name: style, Length: 342441, dtype: object

# %%
pd.crosstab(y, kmeans_model.labels_, rownames=['실제값'], colnames=['k-means값'])
# Out:
# k-means값                      0     1     2    3     4     5     6     7   \
# 실제값
# Abstract_Expressionism      1432   289  1532  227     1  1076   125   366
# Action_painting             5629     3   320   26     0   524     0     0
# Analytical_Cubism             23  1259   560  315     0    76  2250     0
# Art_Nouveau_Modern           465    57   290  213   246  2118   226   362
# Baroque                      480     5     8  102   768   196   421    53
# Color_Field_Painting         167    44   728   43     0   140     0    12
# Contemporary_Realism         381    85   308  209    42   151   196   136
# Cubism                       229  1892  1067  375    67   979   833   529
# Early_Renaissance            706    20    29  154   696   244   723   335
# Expressionism                544   144   808  459  1082  1489   559   464
# Fauvism                      187   117  3632  975   255   171   343  1339
# High_Renaissance            1371     0     0   67  1218   352   520    51
# Impressionism                370    14    68  388   649   186   224   208
# Mannerism_Late_Renaissance   579     0     6   69   932    40  1128    98
# Minimalism                   186    98    48   52     0   135     0     0
# Naive_Art_Primitivism        391    57   746  726   200  1700   131   645
# New_Realism                   39    43     2    2   227   263   129    88
# Northern_Renaissance        2050    12    13   56  1165   519   575   355
# Pointillism                  299     2   792   90   301    40    35   337
# Pop_Art                      174   161   995  162   356  1182    25   895
# Post_Impressionism           724    55   312  857   534   634   288   634
# Realism                      892    24    23  418   815   621    92    61
# Rococo                       232     3     7   23  1587    39   219    11
# Romanticism                  555     0    25   39   860   378   201    50
# Symbolism                   1165    45  1487  273   344   547   234    61
# Synthetic_Cubism              35  8907   124  113     0   131   154     8
# Ukiyo_e                      434    71   415  205     8  3216   302   231
#
# k-means값                      8     9   ...    17    18    19    20    21  \
# 실제값                                     ...
# Abstract_Expressionism       167   334  ...   568   766   141     0    14
# Action_painting              139    29  ...   445    86     0     0     0
# Analytical_Cubism             14     0  ...    16     0     0     0     0
# Art_Nouveau_Modern           673   456  ...  2057    92   506   272   165
# Baroque                      625    46  ...   375     4   650  2012  1948
# Color_Field_Painting           8    44  ...    45  4121     9     0     0
# Contemporary_Realism         697   643  ...   277    19  2756  1023   585
# Cubism                       511   106  ...   703   672   104    66   101
# Early_Renaissance           1874   162  ...   364     0    13   429  1371
# Expressionism                555   381  ...   733    60   271   541   218
# Fauvism                      247   744  ...   232   327   288   183   121
# High_Renaissance             784    98  ...   146     0    82  1644  1873
# Impressionism                478  1143  ...    64     2  3985   425   314
# Mannerism_Late_Renaissance   276   206  ...   409     0    12  2329  1780
# Minimalism                    45     0  ...    25   599    83     0     0
# Naive_Art_Primitivism        400   344  ...  1324   465   818   163   215
# New_Realism                 2392   908  ...   136     0  1950  1820   593
# Northern_Renaissance         890   271  ...   845     0   186  1113  1230
# Pointillism                  321  1745  ...   321     4  3775   343   121
# Pop_Art                      239   203  ...  1256  1551    81    75    17
# Post_Impressionism           466  1053  ...   138    13  2178   448   224
# Realism                      612   344  ...   114     0  3052  1317   500
# Rococo                       530   131  ...   174     0   872  2949  1619
# Romanticism                  499   298  ...   301     2  2642  1161   641
# Symbolism                    534  1091  ...   312     8  1326   221   185
# Synthetic_Cubism              88     0  ...   156   264     0     0     0
# Ukiyo_e                      398  1566  ...  2557    13    26    19    59
#
# k-means값                      22    23    24    25    26
# 실제값
# Abstract_Expressionism        46  1192  1960   244    35
# Action_painting                0   254   517     0     0
# Analytical_Cubism            217     0     0   321   118
# Art_Nouveau_Modern           394  1359   664   165   275
# Baroque                      619   752   297    13   934
# Color_Field_Painting           0  2396  4570    19     4
# Contemporary_Realism         175   757  2253    58   524
# Cubism                        94   370   734  2128   145
# Early_Renaissance            207   158   193   113   737
# Expressionism                219   460   427   858   847
# Fauvism                       73   241   186  1172    95
# High_Renaissance             121   167   214    43   968
# Impressionism               1258    85   115     8   859
# Mannerism_Late_Renaissance    95   167   105     9  1324
# Minimalism                    43  2925  8327     0     2
# Naive_Art_Primitivism        449   798   449   626   245
# New_Realism                 1008   514   541    16   553
# Northern_Renaissance         218   314   166    38   658
# Pointillism                  730   620   156    31   144
# Pop_Art                      141  1677  1901  1032    50
# Post_Impressionism          1233   157   241   179   465
# Realism                      576   292   233     8   649
# Rococo                       851   198    41     2   692
# Romanticism                  581  1008   189    15   624
# Symbolism                    352   534   584    57   406
# Synthetic_Cubism              45   155   370  1440     5
# Ukiyo_e                      171   918   177  1101    96
#
# [27 rows x 27 columns]

# %% [markdown]
# ## 군집모형 성능평가

# %%
VGG_vectors = np.load('../data/VGG_vectors.npy')
painting = pd.read_csv('painting.csv')

X = VGG_vectors
y = painting['style']

le = LabelEncoder()
y_encoded = le.fit_transform(y)  # 문자열 라벨을 숫자로 변환

# %%
len(le.classes_)
# Out:
# 27

# %%
model = KMeans(n_clusters=len(le.classes_), random_state=1, n_init=10)
model.fit(X)
# Out:
# KMeans(n_clusters=27, n_init=10, random_state=1)

# %%
pred = model.predict(X)
all(pred == model.labels_)
# Out:
# True

# %%
# 예측된 클러스터 라벨
pred = model.labels_

# 각 클러스터에서 가장 많이 등장하는 실제 라벨 찾기
mapping = {}
for cluster in range(len(le.classes_)):
    mask = (pred == cluster)
    if np.any(mask):  # 해당 클러스터에 속한 샘플이 존재하는 경우만 실행
        most_common_label = np.bincount(y_encoded[mask]).argmax()
        mapping[cluster] = most_common_label

# 클러스터 인덱스를 실제 라벨과 매핑
adjusted_pred = np.vectorize(mapping.get)(pred)

# 교차표 생성
cross_tab = pd.crosstab(y_encoded, adjusted_pred, rownames=['실제값'], colnames=['예측값'])

# 결과 출력
cross_tab
# Out:
# 예측값   3     4    5    8     9     12   20    21   23   24
# 실제값
# 0    119    27  432    6   490   482  104   611  287  215
# 1      4     0    5    0     9    30    0    42    3    5
# 2      1    21    1    0    10    55    1     8   10    3
# 3    622   202   71  118   793   947  125   735  539  102
# 4    102  1380    3   46    84  1218   18   918  363    4
# 5     12     1  873    1    68    32    3   239  312   74
# 6     13    48   11    1    19   206    7   133   25   18
# 7    107   105  226   10   819   468  100   211   68   82
# 8     49   289    1  263    92   356   38   232   51    6
# 9    329   505   95   39  1616  1963  243  1342  272  242
# 10    23    32   58    2   259   238   94    94   17  105
# 11    21   365    1  126    82   310   10   364   61    1
# 12    57   889   11   31   232  9129  185  1948  130   71
# 13    47   476    0   67    16   272   11   309   77    0
# 14     6     0  396    0    82    38    0   437  342    9
# 15   186   117   95   14   606   607  121   348  148   61
# 16     7    45    4    2     7   165    5    63   12    4
# 17   161   495    5  143   144   589   68   818  115    3
# 18    14    18    5    0    19   356   14    50   22   10
# 19   140    14  278    3   363   156  108   141  179   60
# 20    70   355   38   24   702  3481  284  1193  103  135
# 21    67  1183    6   32   401  5105   46  3436  380   37
# 22    29   583    0   26    15   798    2   492  128    5
# 23   126   909    3   75   187  3213   37  1582  735   32
# 24   103   243   20   51   287  1591   26  1020  230  835
# 25     4     3   48    0    50    86    1     7   16    1
# 26   189    58   15    1   393   190   19   163   83   45

# %%
pred_str = le.inverse_transform(adjusted_pred)
pd.crosstab(y, pred_str)
# Out:
# col_0                       Art_Nouveau_Modern  Baroque  Color_Field_Painting  \
# style
# Abstract_Expressionism                     119       27                   432
# Action_painting                              4        0                     5
# Analytical_Cubism                            1       21                     1
# Art_Nouveau_Modern                         622      202                    71
# Baroque                                    102     1380                     3
# Color_Field_Painting                        12        1                   873
# Contemporary_Realism                        13       48                    11
# Cubism                                     107      105                   226
# Early_Renaissance                           49      289                     1
# Expressionism                              329      505                    95
# Fauvism                                     23       32                    58
# High_Renaissance                            21      365                     1
# Impressionism                               57      889                    11
# Mannerism_Late_Renaissance                  47      476                     0
# Minimalism                                   6        0                   396
# Naive_Art_Primitivism                      186      117                    95
# New_Realism                                  7       45                     4
# Northern_Renaissance                       161      495                     5
# Pointillism                                 14       18                     5
# Pop_Art                                    140       14                   278
# Post_Impressionism                          70      355                    38
# Realism                                     67     1183                     6
# Rococo                                      29      583                     0
# Romanticism                                126      909                     3
# Symbolism                                  103      243                    20
# Synthetic_Cubism                             4        3                    48
# Ukiyo_e                                    189       58                    15
#
# col_0                       Early_Renaissance  Expressionism  Impressionism  \
# style
# Abstract_Expressionism                      6            490            482
# Action_painting                             0              9             30
# Analytical_Cubism                           0             10             55
# Art_Nouveau_Modern                        118            793            947
# Baroque                                    46             84           1218
# Color_Field_Painting                        1             68             32
# Contemporary_Realism                        1             19            206
# Cubism                                     10            819            468
# Early_Renaissance                         263             92            356
# Expressionism                              39           1616           1963
# Fauvism                                     2            259            238
# High_Renaissance                          126             82            310
# Impressionism                              31            232           9129
# Mannerism_Late_Renaissance                 67             16            272
# Minimalism                                  0             82             38
# Naive_Art_Primitivism                      14            606            607
# New_Realism                                 2              7            165
# Northern_Renaissance                      143            144            589
# Pointillism                                 0             19            356
# Pop_Art                                     3            363            156
# Post_Impressionism                         24            702           3481
# Realism                                    32            401           5105
# Rococo                                     26             15            798
# Romanticism                                75            187           3213
# Symbolism                                  51            287           1591
# Synthetic_Cubism                            0             50             86
# Ukiyo_e                                     1            393            190
#
# col_0                       Post_Impressionism  Realism  Romanticism  \
# style
# Abstract_Expressionism                     104      611          287
# Action_painting                              0       42            3
# Analytical_Cubism                            1        8           10
# Art_Nouveau_Modern                         125      735          539
# Baroque                                     18      918          363
# Color_Field_Painting                         3      239          312
# Contemporary_Realism                         7      133           25
# Cubism                                     100      211           68
# Early_Renaissance                           38      232           51
# Expressionism                              243     1342          272
# Fauvism                                     94       94           17
# High_Renaissance                            10      364           61
# Impressionism                              185     1948          130
# Mannerism_Late_Renaissance                  11      309           77
# Minimalism                                   0      437          342
# Naive_Art_Primitivism                      121      348          148
# New_Realism                                  5       63           12
# Northern_Renaissance                        68      818          115
# Pointillism                                 14       50           22
# Pop_Art                                    108      141          179
# Post_Impressionism                         284     1193          103
# Realism                                     46     3436          380
# Rococo                                       2      492          128
# Romanticism                                 37     1582          735
# Symbolism                                   26     1020          230
# Synthetic_Cubism                             1        7           16
# Ukiyo_e                                     19      163           83
#
# col_0                       Symbolism
# style
# Abstract_Expressionism            215
# Action_painting                     5
# Analytical_Cubism                   3
# Art_Nouveau_Modern                102
# Baroque                             4
# Color_Field_Painting               74
# Contemporary_Realism               18
# Cubism                             82
# Early_Renaissance                   6
# Expressionism                     242
# Fauvism                           105
# High_Renaissance                    1
# Impressionism                      71
# Mannerism_Late_Renaissance          0
# Minimalism                          9
# Naive_Art_Primitivism              61
# New_Realism                         4
# Northern_Renaissance                3
# Pointillism                        10
# Pop_Art                            60
# Post_Impressionism                135
# Realism                            37
# Rococo                              5
# Romanticism                        32
# Symbolism                         835
# Synthetic_Cubism                    1
# Ukiyo_e                            45

# %% [markdown]
# ## 조정된 rand지수 외 성능평가 기준 함수

# %%
adjusted_rand_score(labels_true=y, labels_pred=pred_str)
# Out:
# 0.07769517162932903

# %%
adjusted_rand_score(labels_true=y_encoded, labels_pred=pred)
# Out:
# 0.043476740248968304

# %%
homogeneity_score(y, pred_str)
# Out:
# 0.09576844871655185

# %%
completeness_score(y, pred_str)
# Out:
# 0.1512225712738543

# %%
v_measure_score(y, pred_str)
# Out:
# 0.1172702640151675

# %%
mutual_info_score(y, pred_str)
# Out:
# 0.2701851150361978

# %% [markdown]
# # 앙상블모형

# %%
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((239708, 512), (239708,), (102733, 512), (102733,))

# %%
le = LabelEncoder()
train_y = le.fit_transform(train_y)
test_y = le.fit_transform(test_y)

def model_measure(model, train_X=train_X, train_y=train_y, test_X=test_X, test_y=test_y):
    model.fit(train_X, train_y)
    pred = model.predict(test_X)
    accuracy  = model.score(test_X, test_y)
    precision = precision_score(test_y, pred, average="macro")
    recall    = recall_score(test_y, pred, average="macro")
    f1score  = f1_score(test_y, pred, average="macro")
    return '정확도:{:.3f}, 정밀도:{:.3f}, 재현율:{:.3f}, f1_score:{:.3f}'.format(accuracy, precision, recall, f1score)

# %% [markdown]
# # 의사결정 방식

# %% [markdown]
# ## 배깅 방식

# %%
rf = RandomForestClassifier(n_estimators=100,         # 의사결정나무 100개
                            max_features=len(set(y)), # 2개 특징으로 나눔
                            random_state=42).fit(train_X, train_y)
rf.score(test_X, test_y)
# Out:
# 0.8779068069656294

# %% [markdown]
# ## 부스팅 방식

# %%
xgb = model_measure(XGBClassifier())
xgb
# Out:
# '정확도:0.847, 정밀도:0.845, 재현율:0.847, f1_score:0.846'

# %%
lgb = model_measure(LGBMClassifier(force_col_wise=True))
lgb
# Out:
# [LightGBM] [Info] Total Bins 130560
# [LightGBM] [Info] Number of data points in the train set: 239708, number of used features: 512
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295733
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295733
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# [LightGBM] [Info] Start training from score -3.295845
# '정확도:0.801, 정밀도:0.796, 재현율:0.801, f1_score:0.798'

# %% [markdown]
# ## 투표를 이용한 앙상블

# %%
# ✅ 경량화된 랜덤포레스트 모델
rf_model = RandomForestClassifier(
    n_estimators=50,      # 트리 개수 줄이기
    max_depth=5,          # 트리 깊이 제한
    max_features='sqrt',  # 최적의 특징 개수 자동 선택
    random_state=42
)

# ✅ 경량화된 XGBoost 모델
xgb_model = XGBClassifier(
    max_depth=4,          # 트리 깊이 제한
    n_estimators=50,      # 트리 개수 줄이기
    learning_rate=0.1,    # 학습 속도 증가
    subsample=0.8,        # 데이터 일부 샘플링
    colsample_bytree=0.8, # 일부 특성만 사용
    tree_method='hist',   # 히스토그램 기반 트리 (메모리 절약)
    eval_metric='logloss',
#     use_label_encoder=True,
    random_state=42
)

# ✅ 경량화된 LightGBM 모델
lgb_model = LGBMClassifier(
    n_estimators=50,      # 트리 개수 줄이기
    max_depth=4,          # 트리 깊이 제한
    num_leaves=16,        # 리프 개수 줄이기
    subsample=0.8,        # 데이터 일부 샘플링
    colsample_bytree=0.8, # 일부 특성만 사용
    verbose=-1,           # 불필요한 출력 제거
    random_state=42
)
print(model_measure(rf_model))
print(model_measure(xgb_model))
print(model_measure(lgb_model))
# Out:
# 정확도:0.339, 정밀도:0.337, 재현율:0.339, f1_score:0.264
# 정확도:0.575, 정밀도:0.561, 재현율:0.575, f1_score:0.560
# 정확도:0.636, 정밀도:0.622, 재현율:0.636, f1_score:0.625

# %%
voting_model_hard = VotingClassifier(estimators=[('rfm', rf_model),
                                                 ('xgb', xgb_model),
                                                 ('lgb', lgb_model)],
                                     voting='hard') # voting='hard' 기본값
voting_model_hard.fit(X_sampled, y_sampled)
# Out:
# VotingClassifier(estimators=[('rfm',
#                               RandomForestClassifier(max_depth=5,
#                                                      n_estimators=50,
#                                                      random_state=42)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.8, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric='logloss',
#                                             feature_types=None, gamma=Non...
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=4,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=50, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             objective='multi:softprob', ...)),
#                              ('lgb',
#                               LGBMClassifier(colsample_bytree=0.8, max_depth=4,
#                                              n_estimators=50, num_leaves=16,
#                                              random_state=42, subsample=0.8,
#                                              verbose=-1))])

# %%
voting_model_hard.predict(test_X[0].reshape(1, -1))
# Out:
# array(['Northern_Renaissance'], dtype=object)

# %%
# voting 알고리즘 - soft 방식
voting_model_soft = VotingClassifier(estimators=[('rfm', rf_model),
                                                 ('xgb', xgb_model),
                                                 ('lgb', lgb_model)],
                                     voting='soft') # voting='hard' 기본값
voting_model_soft.fit(X_sampled, y_sampled)
# Out:
# VotingClassifier(estimators=[('rfm',
#                               RandomForestClassifier(max_depth=5,
#                                                      n_estimators=50,
#                                                      random_state=42)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.8, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric='logloss',
#                                             feature_types=None, gamma=Non...
#                                             max_delta_step=None, max_depth=4,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=50, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             objective='multi:softprob', ...)),
#                              ('lgb',
#                               LGBMClassifier(colsample_bytree=0.8, max_depth=4,
#                                              n_estimators=50, num_leaves=16,
#                                              random_state=42, subsample=0.8,
#                                              verbose=-1))],
#                  voting='soft')

# %%
voting_model_soft.predict(test_X[0].reshape(1, -1))
# Out:
# array(['Northern_Renaissance'], dtype=object)

# %%
test_y[0]
# Out:
# 17

# %%
inverse_test_y = le.inverse_transform(test_y)
inverse_test_y[0]
# Out:
# 'Northern_Renaissance'

# %%
model_measure(voting_model_hard)
# Out:
# '정확도:0.588, 정밀도:0.576, 재현율:0.588, f1_score:0.568'

# %%
model_measure(voting_model_soft)
# Out:
# '정확도:0.619, 정밀도:0.604, 재현율:0.619, f1_score:0.605'

# %%
# voting_model_hard의 개별 모델들 딕셔너리 형태로 반환
voting_model_hard.named_estimators_
# Out:
# {'rfm': RandomForestClassifier(max_depth=5, n_estimators=50, random_state=42),
#  'xgb': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric='logloss',
#                feature_types=None, gamma=None, grow_policy=None,
#                importance_type=None, interaction_constraints=None,
#                learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#                max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#                max_leaves=None, min_child_weight=None, missing=nan,
#                monotone_constraints=None, multi_strategy=None, n_estimators=50,
#                n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...),
#  'lgb': LGBMClassifier(colsample_bytree=0.8, max_depth=4, n_estimators=50,
#                 num_leaves=16, random_state=42, subsample=0.8, verbose=-1)}

# %%
# voting_model_soft의 개별 모델들 딕셔너리 형태로 반환
voting_model_soft.named_estimators_
# Out:
# {'rfm': RandomForestClassifier(max_depth=5, n_estimators=50, random_state=42),
#  'xgb': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric='logloss',
#                feature_types=None, gamma=None, grow_policy=None,
#                importance_type=None, interaction_constraints=None,
#                learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#                max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#                max_leaves=None, min_child_weight=None, missing=nan,
#                monotone_constraints=None, multi_strategy=None, n_estimators=50,
#                n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...),
#  'lgb': LGBMClassifier(colsample_bytree=0.8, max_depth=4, n_estimators=50,
#                 num_leaves=16, random_state=42, subsample=0.8, verbose=-1)}

# %%
print(model_measure(voting_model_hard.named_estimators_['rfm']))  # 단일모델로 개별모델 access 가능
print(model_measure(voting_model_hard.named_estimators_['xgb']))
print(model_measure(voting_model_hard.named_estimators_['lgb']))
# Out:
# 정확도:0.339, 정밀도:0.337, 재현율:0.339, f1_score:0.264
# 정확도:0.575, 정밀도:0.561, 재현율:0.575, f1_score:0.560
# 정확도:0.636, 정밀도:0.622, 재현율:0.636, f1_score:0.625

# %%
print(model_measure(voting_model_soft.named_estimators_['rfm']))  # 단일모델로 개별모델 access 가능
print(model_measure(voting_model_soft.named_estimators_['xgb']))
print(model_measure(voting_model_soft.named_estimators_['lgb']))
# Out:
# 정확도:0.339, 정밀도:0.337, 재현율:0.339, f1_score:0.264
# 정확도:0.575, 정밀도:0.561, 재현율:0.575, f1_score:0.560
# 정확도:0.636, 정밀도:0.622, 재현율:0.636, f1_score:0.625

# %%
voting_model_hard.get_params()  # 모델 내의 모든 파라미터(하이퍼파라미터)
# Out:
# {'estimators': [('rfm',
#    RandomForestClassifier(max_depth=5, n_estimators=50, random_state=42)),
#   ('xgb',
#    XGBClassifier(base_score=None, booster=None, callbacks=None,
#                  colsample_bylevel=None, colsample_bynode=None,
#                  colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#                  enable_categorical=False, eval_metric='logloss',
#                  feature_types=None, gamma=None, grow_policy=None,
#                  importance_type=None, interaction_constraints=None,
#                  learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#                  max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#                  max_leaves=None, min_child_weight=None, missing=nan,
#                  monotone_constraints=None, multi_strategy=None, n_estimators=50,
#                  n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...)),
#   ('lgb',
#    LGBMClassifier(colsample_bytree=0.8, max_depth=4, n_estimators=50,
#                   num_leaves=16, random_state=42, subsample=0.8, verbose=-1))],
#  'flatten_transform': True,
#  'n_jobs': None,
#  'verbose': False,
#  'voting': 'hard',
#  'weights': None,
#  'rfm': RandomForestClassifier(max_depth=5, n_estimators=50, random_state=42),
#  'xgb': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric='logloss',
#                feature_types=None, gamma=None, grow_policy=None,
#                importance_type=None, interaction_constraints=None,
#                learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#                max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#                max_leaves=None, min_child_weight=None, missing=nan,
#                monotone_constraints=None, multi_strategy=None, n_estimators=50,
#                n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...),
#  'lgb': LGBMClassifier(colsample_bytree=0.8, max_depth=4, n_estimators=50,
#                 num_leaves=16, random_state=42, subsample=0.8, verbose=-1),
#  'rfm__bootstrap': True,
#  'rfm__ccp_alpha': 0.0,
#  'rfm__class_weight': None,
#  'rfm__criterion': 'gini',
#  'rfm__max_depth': 5,
#  'rfm__max_features': 'sqrt',
#  'rfm__max_leaf_nodes': None,
#  'rfm__max_samples': None,
#  'rfm__min_impurity_decrease': 0.0,
#  'rfm__min_samples_leaf': 1,
#  'rfm__min_samples_split': 2,
#  'rfm__min_weight_fraction_leaf': 0.0,
#  'rfm__n_estimators': 50,
#  'rfm__n_jobs': None,
#  'rfm__oob_score': False,
#  'rfm__random_state': 42,
#  'rfm__verbose': 0,
#  'rfm__warm_start': False,
#  'xgb__objective': 'multi:softprob',
#  'xgb__base_score': None,
#  'xgb__booster': None,
#  'xgb__callbacks': None,
#  'xgb__colsample_bylevel': None,
#  'xgb__colsample_bynode': None,
#  'xgb__colsample_bytree': 0.8,
#  'xgb__device': None,
#  'xgb__early_stopping_rounds': None,
#  'xgb__enable_categorical': False,
#  'xgb__eval_metric': 'logloss',
#  'xgb__feature_types': None,
#  'xgb__gamma': None,
#  'xgb__grow_policy': None,
#  'xgb__importance_type': None,
#  'xgb__interaction_constraints': None,
#  'xgb__learning_rate': 0.1,
#  'xgb__max_bin': None,
#  'xgb__max_cat_threshold': None,
#  'xgb__max_cat_to_onehot': None,
#  'xgb__max_delta_step': None,
#  'xgb__max_depth': 4,
#  'xgb__max_leaves': None,
#  'xgb__min_child_weight': None,
#  'xgb__missing': nan,
#  'xgb__monotone_constraints': None,
#  'xgb__multi_strategy': None,
#  'xgb__n_estimators': 50,
#  'xgb__n_jobs': None,
#  'xgb__num_parallel_tree': None,
#  'xgb__random_state': 42,
#  'xgb__reg_alpha': None,
#  'xgb__reg_lambda': None,
#  'xgb__sampling_method': None,
#  'xgb__scale_pos_weight': None,
#  'xgb__subsample': 0.8,
#  'xgb__tree_method': 'hist',
#  'xgb__validate_parameters': None,
#  'xgb__verbosity': None,
#  'lgb__boosting_type': 'gbdt',
#  'lgb__class_weight': None,
#  'lgb__colsample_bytree': 0.8,
#  'lgb__importance_type': 'split',
#  'lgb__learning_rate': 0.1,
#  'lgb__max_depth': 4,
#  'lgb__min_child_samples': 20,
#  'lgb__min_child_weight': 0.001,
#  'lgb__min_split_gain': 0.0,
#  'lgb__n_estimators': 50,
#  'lgb__n_jobs': None,
#  'lgb__num_leaves': 16,
#  'lgb__objective': None,
#  'lgb__random_state': 42,
#  'lgb__reg_alpha': 0.0,
#  'lgb__reg_lambda': 0.0,
#  'lgb__subsample': 0.8,
#  'lgb__subsample_for_bin': 200000,
#  'lgb__subsample_freq': 0,
#  'lgb__verbose': -1}

# %%
voting_model_soft.get_params()  # 모델 내의 모든 파라미터(하이퍼파라미터)
# Out:
# {'estimators': [('rfm',
#    RandomForestClassifier(max_depth=5, n_estimators=50, random_state=42)),
#   ('xgb',
#    XGBClassifier(base_score=None, booster=None, callbacks=None,
#                  colsample_bylevel=None, colsample_bynode=None,
#                  colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#                  enable_categorical=False, eval_metric='logloss',
#                  feature_types=None, gamma=None, grow_policy=None,
#                  importance_type=None, interaction_constraints=None,
#                  learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#                  max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#                  max_leaves=None, min_child_weight=None, missing=nan,
#                  monotone_constraints=None, multi_strategy=None, n_estimators=50,
#                  n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...)),
#   ('lgb',
#    LGBMClassifier(colsample_bytree=0.8, max_depth=4, n_estimators=50,
#                   num_leaves=16, random_state=42, subsample=0.8, verbose=-1))],
#  'flatten_transform': True,
#  'n_jobs': None,
#  'verbose': False,
#  'voting': 'soft',
#  'weights': None,
#  'rfm': RandomForestClassifier(max_depth=5, n_estimators=50, random_state=42),
#  'xgb': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric='logloss',
#                feature_types=None, gamma=None, grow_policy=None,
#                importance_type=None, interaction_constraints=None,
#                learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#                max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#                max_leaves=None, min_child_weight=None, missing=nan,
#                monotone_constraints=None, multi_strategy=None, n_estimators=50,
#                n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...),
#  'lgb': LGBMClassifier(colsample_bytree=0.8, max_depth=4, n_estimators=50,
#                 num_leaves=16, random_state=42, subsample=0.8, verbose=-1),
#  'rfm__bootstrap': True,
#  'rfm__ccp_alpha': 0.0,
#  'rfm__class_weight': None,
#  'rfm__criterion': 'gini',
#  'rfm__max_depth': 5,
#  'rfm__max_features': 'sqrt',
#  'rfm__max_leaf_nodes': None,
#  'rfm__max_samples': None,
#  'rfm__min_impurity_decrease': 0.0,
#  'rfm__min_samples_leaf': 1,
#  'rfm__min_samples_split': 2,
#  'rfm__min_weight_fraction_leaf': 0.0,
#  'rfm__n_estimators': 50,
#  'rfm__n_jobs': None,
#  'rfm__oob_score': False,
#  'rfm__random_state': 42,
#  'rfm__verbose': 0,
#  'rfm__warm_start': False,
#  'xgb__objective': 'multi:softprob',
#  'xgb__base_score': None,
#  'xgb__booster': None,
#  'xgb__callbacks': None,
#  'xgb__colsample_bylevel': None,
#  'xgb__colsample_bynode': None,
#  'xgb__colsample_bytree': 0.8,
#  'xgb__device': None,
#  'xgb__early_stopping_rounds': None,
#  'xgb__enable_categorical': False,
#  'xgb__eval_metric': 'logloss',
#  'xgb__feature_types': None,
#  'xgb__gamma': None,
#  'xgb__grow_policy': None,
#  'xgb__importance_type': None,
#  'xgb__interaction_constraints': None,
#  'xgb__learning_rate': 0.1,
#  'xgb__max_bin': None,
#  'xgb__max_cat_threshold': None,
#  'xgb__max_cat_to_onehot': None,
#  'xgb__max_delta_step': None,
#  'xgb__max_depth': 4,
#  'xgb__max_leaves': None,
#  'xgb__min_child_weight': None,
#  'xgb__missing': nan,
#  'xgb__monotone_constraints': None,
#  'xgb__multi_strategy': None,
#  'xgb__n_estimators': 50,
#  'xgb__n_jobs': None,
#  'xgb__num_parallel_tree': None,
#  'xgb__random_state': 42,
#  'xgb__reg_alpha': None,
#  'xgb__reg_lambda': None,
#  'xgb__sampling_method': None,
#  'xgb__scale_pos_weight': None,
#  'xgb__subsample': 0.8,
#  'xgb__tree_method': 'hist',
#  'xgb__validate_parameters': None,
#  'xgb__verbosity': None,
#  'lgb__boosting_type': 'gbdt',
#  'lgb__class_weight': None,
#  'lgb__colsample_bytree': 0.8,
#  'lgb__importance_type': 'split',
#  'lgb__learning_rate': 0.1,
#  'lgb__max_depth': 4,
#  'lgb__min_child_samples': 20,
#  'lgb__min_child_weight': 0.001,
#  'lgb__min_split_gain': 0.0,
#  'lgb__n_estimators': 50,
#  'lgb__n_jobs': None,
#  'lgb__num_leaves': 16,
#  'lgb__objective': None,
#  'lgb__random_state': 42,
#  'lgb__reg_alpha': 0.0,
#  'lgb__reg_lambda': 0.0,
#  'lgb__subsample': 0.8,
#  'lgb__subsample_for_bin': 200000,
#  'lgb__subsample_freq': 0,
#  'lgb__verbose': -1}

# %% [markdown]
# ## 머신러닝 모형 저장

# %%
# 대용량 모형일 때 : joblib 파일로 저장 (joblib 라이브러리 사용)
print(joblib.dump(voting_model_hard, 'voting_model_hard.joblib'))
print(joblib.dump(voting_model_soft, 'voting_model_soft.joblib'))
# Out:
# ['voting_model_hard.joblib']
# ['voting_model_soft.joblib']

# %%
# 모델 load
loaded_voting_model_hard = joblib.load('voting_model_hard.joblib')
model_measure(loaded_voting_model_hard)
# Out:
# '정확도:0.588, 정밀도:0.576, 재현율:0.588, f1_score:0.568'

# %%
# 모델 load
loaded_voting_model_soft = joblib.load('voting_model_soft.joblib')
model_measure(loaded_voting_model_soft)
# Out:
# '정확도:0.619, 정밀도:0.604, 재현율:0.619, f1_score:0.605'
