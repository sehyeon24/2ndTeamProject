# %%
import os
import joblib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier  # 분류분석
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score, fbeta_score
from sklearn.metrics import adjusted_rand_score, homogeneity_score, completeness_score, v_measure_score, mutual_info_score
from sklearn.neural_network import MLPClassifier
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, VotingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import BaggingClassifier

# %%
# 그래프 저장 시 해상도 높게
# %config InlineBackend.figure_format = 'retina'

# 한글설정
# plt.rc('font', family='Malgun Gothic')  # 윈도우즈
# plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rc('font', family='AppleGothic') # Mac 운영체제
plt.rc('axes', unicode_minus=False)  # 축의 -(마이너스) 깨짐 방지

# %%
os.environ['OMP_NUM_THREADS'] = '1'

# %% [markdown]
# # data load

# %%
filepath = '../team_project/data/'

# %%
VGG_vectors = np.load(os.path.join(filepath,'VGG_vectors.npy'))
VGG_vectors.shape
# Out:
# (80158, 512)

# %%
painting = pd.read_csv(os.path.join(filepath,'painting.csv'))
painting.head()
# Out:
#                                                 file  \
# 0  Realism/vincent-van-gogh_pine-trees-in-the-fen...
# 1  Baroque/rembrandt_the-angel-appearing-to-the-s...
# 2  Post_Impressionism/paul-cezanne_portrait-of-th...
# 3  Impressionism/pierre-auguste-renoir_young-girl...
# 4       Romanticism/ivan-aivazovsky_morning-1851.jpg
#
#                                        title                 artist  \
# 0                 pine-trees-in-the-fen-1884       vincent-van-gogh
# 1  the-angel-appearing-to-the-shepherds-1634              rembrandt
# 2               portrait-of-the-artist-s-son           paul-cezanne
# 3         young-girl-seated-in-a-meadow-1916  pierre-auguste-renoir
# 4                               morning-1851        ivan-aivazovsky
#
#                 genre               style
# 0           landscape             Realism
# 1  religious painting             Baroque
# 2            portrait  Post_Impressionism
# 3      genre painting       Impressionism
# 4              marina         Romanticism

# %%
X = VGG_vectors
y = painting['genre']
X, y
# Out:
# (array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.13876809,  0.        ],
#         [ 0.        ,  0.        ,  7.3608236 , ...,  0.        ,
#           2.1667717 ,  0.        ],
#         [17.689674  ,  2.8541045 ,  6.410571  , ...,  3.4064777 ,
#           0.52448237, 10.3166    ],
#         ...,
#         [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  0.        ],
#         [ 0.        ,  0.        , 20.376156  , ...,  0.6702498 ,
#           1.7302468 ,  4.738069  ],
#         [ 4.411827  ,  0.99009806, 33.64073   , ...,  6.051113  ,
#           0.19890343, 24.475027  ]], dtype=float32),
#  0                 landscape
#  1        religious painting
#  2                  portrait
#  3            genre painting
#  4                    marina
#                  ...
#  80153       animal painting
#  80154                design
#  80155       flower painting
#  80156       animal painting
#  80157        genre painting
#  Name: genre, Length: 80158, dtype: object)

# %%
print(pd.Series(y).value_counts())
# Out:
# portrait                    14294
# landscape                   13478
# genre painting              11089
# religious painting           6694
# abstract                     5264
# cityscape                    4686
# sketch and study             3959
# still life                   2907
# illustration                 1914
# nude painting                1912
# mythological painting        1367
# marina                       1351
# design                       1311
# flower painting              1275
# self-portrait                1193
# figurative                   1020
# animal painting               908
# symbolic painting             723
# sculpture                     704
# history painting              616
# allegorical painting          604
# interior                      508
# literary painting             402
# battle painting               268
# caricature                    263
# poster                        261
# installation                  256
# veduta                        156
# cloudscape                    155
# wildlife painting             116
# photo                         115
# pastorale                      75
# nude painting (nu)             66
# capriccio                      56
# advertisement                  52
# vanitas                        31
# bird-and-flower painting       26
# yakusha-e                      20
# quadratura                     17
# panorama                       15
# Canadian                       13
# miniature                      11
# graffiti                        4
# tessellation                    3
# Name: genre, dtype: int64

# %%
# 독립변수 스케일 조정
smote = SMOTE(sampling_strategy='auto', k_neighbors=2) # 특정 클래스의 샘플수가 3개 미만이라 k_neighbors=2
X, y = smote.fit_resample(X, y)

# %%
undersample = NearMiss(version=1)
X_sampled, y_sampled = undersample.fit_resample(X, y)

# %%
pd.Series(y_sampled).value_counts()
# Out:
# Canadian                    14294
# abstract                    14294
# mythological painting       14294
# nude painting               14294
# nude painting (nu)          14294
# panorama                    14294
# pastorale                   14294
# photo                       14294
# portrait                    14294
# poster                      14294
# quadratura                  14294
# religious painting          14294
# sculpture                   14294
# self-portrait               14294
# sketch and study            14294
# still life                  14294
# symbolic painting           14294
# tessellation                14294
# vanitas                     14294
# veduta                      14294
# wildlife painting           14294
# miniature                   14294
# marina                      14294
# literary painting           14294
# cloudscape                  14294
# advertisement               14294
# allegorical painting        14294
# animal painting             14294
# battle painting             14294
# bird-and-flower painting    14294
# capriccio                   14294
# caricature                  14294
# cityscape                   14294
# design                      14294
# landscape                   14294
# figurative                  14294
# flower painting             14294
# genre painting              14294
# graffiti                    14294
# history painting            14294
# illustration                14294
# installation                14294
# interior                    14294
# yakusha-e                   14294
# Name: genre, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sampled, y_sampled, 
                                                    test_size=0.3, 
                                                    shuffle=True,  # 분할 전 데이터 섞기
                                                    stratify=y_sampled     # 층화추출
                                                   )
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((440255, 512), (188681, 512), (440255,), (188681,))

# %% [markdown]
# # 분류분석

# %% [markdown]
# ## DecisionTreeClassifier

# %%
# 의사결정나무를 구현한 DecisionTreeClassifier를 통한 모형
dt_model = DecisionTreeClassifier(random_state=1)
dt_model = dt_model.fit(X_train, y_train)  # 머신러닝에서는 fit시 독립변수에 array로
dt_model
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
dt_model.score(X_test, y_test)
# Out:
# 0.8471547214610904

# %%
y_dt_pred = dt_model.predict(X_test)
pd.crosstab(y_test, y_dt_pred)  # y_test : 실제값, y_dt_pred : 예측값
# Out:
# col_0                     Canadian  abstract  advertisement  \
# genre
# Canadian                      4287         0              0
# abstract                         1      2679              5
# advertisement                    0         0           4279
# allegorical painting             0        19              2
# animal painting                  2        30              3
# battle painting                  0        10              0
# bird-and-flower painting         0         0              0
# capriccio                        0         0              0
# caricature                       0         5              0
# cityscape                        1        66              7
# cloudscape                       0         6              0
# design                           1        60              6
# figurative                       2        90              7
# flower painting                  0        23              1
# genre painting                   4       106              2
# graffiti                         0         0              0
# history painting                 1        10              0
# illustration                     1        42              3
# installation                     0        20              0
# interior                         0        17              0
# landscape                        3       154              8
# literary painting                0         9              0
# marina                           0        29              1
# miniature                        0         0              0
# mythological painting            0        30              3
# nude painting                    0        37              0
# illustration                             35             0        0       1
# installation                              2             0        0       4
# interior                                 11             0        0       2
# landscape                                81             0        2      28
# literary painting                         7             0        0       0
# marina                                   26             0        0       9
# miniature                                 0             0        0       0
# mythological painting                    26             0        1       2
# nude painting                            40             0        2       0
# nude painting (nu)                        0             0        0       0
# panorama                                  0             0        0       0
# pastorale                                 1             0        0       0
# photo                                     3             0        0       0
# portrait                                 85             0        5       2
# poster                                    7             0        1       0
# quadratura                                0             0        0       0
# religious painting                       73             0        4       4
# sculpture                                 8             0        0       0
# self-portrait                            25             0        0       0
# sketch and study                         35             0        2       1
# still life                               64             0        9       1
# symbolic painting                      3667             0        2       0
# tessellation                              0          4287        0       0
# vanitas                                   0             0     4281       0
# veduta                                    0             0        0    4255
# wildlife painting                         2             0        0       0
# yakusha-e                                 0             0        0       0
#
# col_0                     wildlife painting  yakusha-e
# genre
# Canadian                                  0          0
# abstract                                  5          0
# advertisement                             0          0
# allegorical painting                      0          0
# animal painting                           6          0
# battle painting                           0          0
# bird-and-flower painting                  0          0
# capriccio                                 0          0
# caricature                                0          0
# cityscape                                 9          1
# cloudscape                                0          0
# design                                    1          0
# figurative                                2          1
# flower painting                           2          2
# genre painting                           15          5
# graffiti                                  0          0
# history painting                          0          0
# illustration                              1          0
# installation                              0          0
# interior                                  1          0
# landscape                                26          0
# literary painting                         1          1
# marina                                    6          0
# miniature                                 0          0
# mythological painting                     4          0
# nude painting                             9          0
# nude painting (nu)                        0          0
# panorama                                  0          0
# pastorale                                 0          0
# photo                                     0          0
# portrait                                 10          4
# poster                                    0          0
# quadratura                                0          0
# religious painting                       12          1
# sculpture                                 1          0
# self-portrait                             3          0
# sketch and study                          4          2
# still life                               11          3
# symbolic painting                         3          0
# tessellation                              0          0
# vanitas                                   0          0
# veduta                                    0          0
# wildlife painting                      4259          0
# yakusha-e                                 0       4285
#
# [44 rows x 44 columns]

# %%
# y_test는 실제 정답 (원-핫 인코딩된 경우 argmax로 변환)
y_test_labels = y_test
y_pred_labels = y_dt_pred

# 상세한 성능 지표 출력
print(" Classification Report:")
print(classification_report(y_test_labels, y_pred_labels, digits=4))

# 개별 지표 계산 (매크로 평균 사용)
precision = precision_score(y_test_labels, y_pred_labels, average='macro')
recall = recall_score(y_test_labels, y_pred_labels, average='macro')
f1 = f1_score(y_test_labels, y_pred_labels, average='macro')

print(f" Precision: {precision:.4f}")
print(f" Recall: {recall:.4f}")
print(f" F1-score: {f1:.4f}")
# Out:
#  Classification Report:
#                           precision    recall  f1-score   support
#
#                 Canadian     0.9956    0.9998    0.9977      4288
#                 abstract     0.6912    0.6246    0.6562      4289
#            advertisement     0.9821    0.9977    0.9898      4289
#     allegorical painting     0.8284    0.8829    0.8548      4288
#          animal painting     0.7996    0.8293    0.8142      4288
#          battle painting     0.9173    0.9681    0.9420      4288
# bird-and-flower painting     0.9926    0.9984    0.9955      4288
#                capriccio     0.9889    0.9958    0.9923      4289
#               caricature     0.9497    0.9783    0.9638      4288
#                cityscape     0.6477    0.6134    0.6301      4289
#               cloudscape     0.9506    0.9862    0.9681      4288
#                   design     0.7711    0.8004    0.7854      4288
#               figurative     0.7851    0.8120    0.7983      4288
#          flower painting     0.8632    0.8839    0.8734      4289
#           genre painting     0.2765    0.2281    0.2500      4288
#                 graffiti     0.9984    0.9998    0.9991      4288
#         history painting     0.8342    0.8955    0.8638      4288
#             illustration     0.7291    0.7369    0.7330      4288
#             installation     0.9575    0.9781    0.9677      4288
#                 interior     0.8856    0.9242    0.9045      4288
#                landscape     0.4506    0.3640    0.4027      4288
#        literary painting     0.8694    0.9343    0.9007      4289
#                   marina     0.7788    0.8284    0.8028      4288
#                miniature     0.9981    0.9998    0.9990      4288
#    mythological painting     0.7259    0.7558    0.7405      4288
#            nude painting     0.7178    0.7194    0.7186      4288
#       nude painting (nu)     0.9728    0.9937    0.9832      4288
#                 panorama     0.9972    1.0000    0.9986      4288
#                pastorale     0.9786    0.9935    0.9860      4288
#                    photo     0.9701    0.9909    0.9804      4288
#                 portrait     0.4397    0.3357    0.3808      4289
#                   poster     0.9557    0.9806    0.9680      4288
#               quadratura     0.9972    0.9993    0.9983      4289
#       religious painting     0.4467    0.3909    0.4169      4288
#                sculpture     0.9012    0.9167    0.9089      4288
#            self-portrait     0.7985    0.8347    0.8162      4288
#         sketch and study     0.6397    0.6294    0.6345      4288
#               still life     0.6777    0.6364    0.6564      4288
#        symbolic painting     0.8081    0.8550    0.8309      4289
#             tessellation     0.9998    0.9998    0.9998      4288
#                  vanitas     0.9889    0.9984    0.9936      4288
#                   veduta     0.9741    0.9923    0.9831      4288
#        wildlife painting     0.9699    0.9932    0.9814      4288
#                yakusha-e     0.9954    0.9993    0.9973      4288
#
#                 accuracy                         0.8472    188681
#                macro avg     0.8386    0.8472    0.8422    188681
#             weighted avg     0.8386    0.8472    0.8422    188681
#
#  Precision: 0.8386
#  Recall: 0.8472
#  F1-score: 0.8422

# %%
print(fbeta_score(y_test, y_dt_pred, beta=0.5, average='macro'))# fbeta score의 beta=1 : f1 score
print(fbeta_score(y_test, y_dt_pred, beta=1, average='macro')) # fbeta score의 2>=beta>1 : recall의 가중치가 높게 조정된 f1 score
print(fbeta_score(y_test, y_dt_pred, beta=2, average='macro')) # fbeta score의 0<=beta<1 : precision의 가중치가 높게 조정된 f1 score
# Out:
# 0.8398610081385957
# 0.8422338881955447
# 0.8450519009428816

# %% [markdown]
# ## MLPClassifier

# %%
# 다중신경망 모형
mlp_model = MLPClassifier(hidden_layer_sizes=(38, 64, 32), 
                          max_iter=500,
                         random_state=1) # 중심점 이동 
                          
mlp_model = mlp_model.fit(X_train, y_train)
mlp_model
# Out:
# MLPClassifier(hidden_layer_sizes=(38, 64, 32), max_iter=500, random_state=1)

# %%
mlp_model.score(X_test, y_test)
# Out:
# 0.8397453903678695

# %%
y_mlp_pred = mlp_model.predict(X_test)
mlp_result = pd.crosstab(y_test, y_mlp_pred)
mlp_result
# Out:
# col_0                     Canadian  abstract  advertisement  \
# genre
# Canadian                      4288         0              0
# abstract                         1      2676              1
# advertisement                    0         0           4289
# allegorical painting             0         1              0
# genre
# Canadian                                  0             0        0       0
# abstract                                 98             0        2       0
# advertisement                             0             0        0       0
# allegorical painting                     42             0        4       0
# animal painting                          59             0        0       0
# battle painting                           6             0        0       0
# bird-and-flower painting                  0             0        0       0
# capriccio                                 0             0        0       0
# caricature                                0             0        0       0
# cityscape                                51             1        0      40
# cloudscape                                0             0        0       0
# design                                   30             1        1       1
# figurative                               55             0        2       0
# flower painting                          29             0        0       0
# genre painting                          153             1        4       0
# graffiti                                  0             0        0       0
# history painting                         25             0        0       0
# illustration                            137             0        1       0
# installation                              0             0        0       0
# interior                                 14             0        0       1
# landscape                               109             0        0      10
# literary painting                        38             0        0       2
# marina                                   62             0        0       5
# miniature                                 0             0        0       0
# mythological painting                   150             0        0       1
# nude painting                           109             0        1       0
# nude painting (nu)                        0             0        0       0
# panorama                                  0             0        0       0
# pastorale                                 8             0        0       0
# photo                                    12             0        0       0
# portrait                                137             0        5       0
# poster                                    1             0        0       0
# quadratura                                0             0        0       0
# religious painting                      145             0        7       0
# sculpture                                 5             0        0       0
# self-portrait                            23             0        1       0
# sketch and study                         95             0        0       0
# still life                               57             0        9       0
# symbolic painting                      4046             0        0       0
# tessellation                              0          4288        0       0
# vanitas                                   0             0     4288       0
# veduta                                    0             0        0    4279
# wildlife painting                         0             0        0       0
# yakusha-e                                 0             0        0       0
#
# col_0                     wildlife painting  yakusha-e
# genre
# Canadian                                  0          0
# abstract                                  5          0
# advertisement                             0          0
# allegorical painting                      1          0
# animal painting                          25          0
# battle painting                           0          0
# bird-and-flower painting                  0          0
# capriccio                                 0          0
# caricature                                0          0
# cityscape                                 0          0
# cloudscape                                0          0
# design                                    4          0
# figurative                                2          0
# flower painting                           2          0
# genre painting                            5          2
# graffiti                                  0          0
# history painting                          1          0
# illustration                              5          0
# installation                              0          0
# interior                                  0          0
# landscape                                19          0
# literary painting                         0          0
# marina                                    0          0
# miniature                                 0          0
# mythological painting                    10          0
# nude painting                             4          0
# nude painting (nu)                        0          0
# panorama                                  0          0
# pastorale                                 0          0
# photo                                     0          0
# portrait                                  4          1
# poster                                    0          0
# quadratura                                0          0
# religious painting                        5          0
# sculpture                                 0          0
# self-portrait                             0          1
# sketch and study                          0          0
# still life                                2          2
# symbolic painting                         2          0
# tessellation                              0          0
# vanitas                                   0          0
# veduta                                    0          0
# wildlife painting                      4281          0
# yakusha-e                                 0       4288
#
# [44 rows x 44 columns]

# %%
# y_test는 실제 정답 (원-핫 인코딩된 경우 argmax로 변환)
y_test_labels = y_test
y_pred_labels = y_mlp_pred  # 모델 예측값도 동일하게 변환

# 상세한 성능 지표 출력
print(" Classification Report:")
print(classification_report(y_test_labels, y_pred_labels, digits=4))

# 개별 지표 계산 (매크로 평균 사용)
precision = precision_score(y_test_labels, y_pred_labels, average='macro')
recall = recall_score(y_test_labels, y_pred_labels, average='macro')
f1 = f1_score(y_test_labels, y_pred_labels, average='macro')

print(f" Precision: {precision:.4f}")
print(f" Recall: {recall:.4f}")
print(f" F1-score: {f1:.4f}")
# Out:
#  Classification Report:
#                           precision    recall  f1-score   support
#
#                 Canadian     0.9974    1.0000    0.9987      4288
#                 abstract     0.7319    0.6239    0.6736      4289
#            advertisement     0.9853    1.0000    0.9926      4289
#     allegorical painting     0.8334    0.8624    0.8477      4288
#          animal painting     0.7989    0.8468    0.8221      4288
#          battle painting     0.9431    0.9774    0.9599      4288
# bird-and-flower painting     0.9974    0.9981    0.9978      4288
#                capriccio     0.9958    0.9984    0.9971      4289
#               caricature     0.9734    0.9741    0.9738      4288
#                cityscape     0.7126    0.5994    0.6511      4289
#               cloudscape     0.9779    0.9916    0.9847      4288
#                   design     0.6456    0.7976    0.7136      4288
#               figurative     0.7037    0.7910    0.7448      4288
#          flower painting     0.8543    0.8547    0.8545      4289
#           genre painting     0.2899    0.2031    0.2389      4288
#                 graffiti     1.0000    1.0000    1.0000      4288
#         history painting     0.8545    0.8710    0.8627      4288
#             illustration     0.5114    0.6880    0.5867      4288
#             installation     0.9642    0.9916    0.9777      4288
#                 interior     0.9344    0.9128    0.9234      4288
#                landscape     0.5617    0.4841    0.5200      4288
#        literary painting     0.8802    0.9555    0.9163      4289
#                   marina     0.7746    0.8309    0.8018      4288
#                miniature     0.9986    1.0000    0.9993      4288
#    mythological painting     0.5939    0.5385    0.5648      4288
#            nude painting     0.7036    0.5763    0.6336      4288
#       nude painting (nu)     0.9480    0.9993    0.9730      4288
#                 panorama     0.9965    1.0000    0.9983      4288
#                pastorale     0.9880    0.9967    0.9923      4288
#                    photo     0.9838    0.9928    0.9883      4288
#                 portrait     0.5076    0.3598    0.4211      4289
#                   poster     0.9618    0.9932    0.9773      4288
#               quadratura     0.9961    1.0000    0.9980      4289
#       religious painting     0.4668    0.2757    0.3466      4288
#                sculpture     0.9286    0.9741    0.9508      4288
#            self-portrait     0.6625    0.8461    0.7431      4288
#         sketch and study     0.6144    0.5499    0.5804      4288
#               still life     0.6832    0.6544    0.6685      4288
#        symbolic painting     0.7103    0.9433    0.8104      4289
#             tessellation     0.9993    1.0000    0.9997      4288
#                  vanitas     0.9914    1.0000    0.9957      4288
#                   veduta     0.9862    0.9979    0.9920      4288
#        wildlife painting     0.9781    0.9984    0.9881      4288
#                yakusha-e     0.9986    1.0000    0.9993      4288
#
#                 accuracy                         0.8397    188681
#                macro avg     0.8322    0.8397    0.8332    188681
#             weighted avg     0.8322    0.8397    0.8332    188681
#
#  Precision: 0.8322
#  Recall: 0.8397
#  F1-score: 0.8332

# %%
print(fbeta_score(y_test, y_mlp_pred, beta=0.5, average='macro')) # fbeta score의 beta=1 : f1 score
print(fbeta_score(y_test, y_mlp_pred, beta=1, average='macro')) # 2>=beta>1 : recall의 가중치가 높게 조정된 f1 score
print(fbeta_score(y_test, y_mlp_pred, beta=2, average='macro')) # 0<=beta<1 : precision의 가중치가 높게 조정된 f1 score
# Out:
# 0.8318878397366892
# 0.8331852171842804
# 0.836473301974166

# %% [markdown]
# # 군집분석

# %% [markdown]
# ## KMeans 클러스터링

# %%
len(set(y))
# Out:
# 44

# %%
kmeans_model = KMeans(n_clusters=len(set(y)),  # 클러스터 갯수:2개의 그룹으로 나눔
               init='random', # random(중심초기점이 random)
               n_init=5,
               max_iter=300)  # 300번 중심점 이동
kmeans_model.fit(X)
# Out:
# KMeans(init='random', n_clusters=44, n_init=5)

# %%
kmeans_model.cluster_centers_  # 최종 두 클러스터의 중심점
# Out:
# array([[0.21165824, 0.3688122 , 6.220317  , ..., 1.2366172 , 0.13267839,
#         2.3576405 ],
#        [4.2272305 , 0.715013  , 6.345366  , ..., 0.21372253, 1.9048864 ,
#         1.525845  ],
#        [1.8401865 , 0.75162697, 2.8953836 , ..., 0.1647445 , 1.1354598 ,
#         1.2211778 ],
#        ...,
#        [2.015356  , 3.783264  , 4.0577197 , ..., 0.75075126, 1.9496106 ,
#         1.4889381 ],
#        [1.5777566 , 0.96769154, 3.105816  , ..., 0.06336528, 2.2397072 ,
#         0.7422844 ],
#        [0.1630435 , 0.43954897, 6.260829  , ..., 0.3842915 , 0.42215168,
#         0.76618266]], dtype=float32)

# %%
len(kmeans_model.cluster_centers_)
# Out:
# 44

# %%
pred = kmeans_model.predict(X)
print(' 예 측 값 : ', pred)
print('modelLabel: ', kmeans_model.labels_)
print(' 실제 y값 : ', y)
# Out:
#  예 측 값 :  [32 33  9 ... 37 37 41]
# modelLabel:  [32 33  9 ... 37 37 41]
#  실제 y값 :  0                  landscape
# 1         religious painting
# 2                   portrait
# 3             genre painting
# 4                     marina
#                  ...
# 628931             yakusha-e
# 628932             yakusha-e
# 628933             yakusha-e
# 628934             yakusha-e
# 628935             yakusha-e
# Name: genre, Length: 628936, dtype: object

# %%
pd.crosstab(y, kmeans_model.labels_, rownames=['실제값'], colnames=['k-means값'])
# Out:
# k-means값                    0     1     2     3     4     5     6     7   \
# 실제값
# Canadian                     0     0     0     0     0     0     0     0
# abstract                   459   108  1548   504    32     0    35   742
# advertisement              526     0     0   122     0     0     0    12
# allegorical painting       248   201   790    19     5     0    22   597
# animal painting            359   366  1216    12     0   564     7   965
# battle painting            505   574  2198    61     0     0   163   384
# bird-and-flower painting  2117     0     0     0     0     0     0  3133
# capriccio                    0  2370  1830     0     0     0  2452     0
# caricature                5608   158   429     0     0    12     0  1880
# cityscape                   74  2558   846    60     2     2  3219   128
# cloudscape                   6   650  2279   398     0     0    53    61
# design                     250   168   356     9    45     0    35  1912
# figurative                 423    61   456   203     9     5     2  2082
# flower painting            118   120  1381    10     1     0     3   200
# genre painting             214   955   931    63     1    33   328   353
# graffiti                     0     0     0     0     0     0     0     0
# history painting           159   700  1434    48     0     0   139    52
# illustration              2456   163   631    12     0     1    55  1507
# installation                47   153   332  4778    33     0    75   277
# interior                    84   392  1298   247     0     0    55   122
# landscape                  131  1713  2206    80     1     0   626   117
# literary painting          233   289  1688    26    21     0    28   329
# marina                      28  1283  1495   248     7     0  1644   148
# miniature                    0     0     0     0     0     0     0  3120
# mythological painting      194   142  1389     0    27    18    10   355
# nude painting              313   118   497    14     0    12     0  1198
# nude painting (nu)         904    65    54     0     0     0     0     0
# wildlife painting            0   896  ...    11     0  3322   580     0   422
# yakusha-e                 1131     0  ...     0     0     0   454     0     0
#
# k-means값                    40    41    42    43
# 실제값
# Canadian                     0  1760     0     0
# abstract                     0    54     2     2
# advertisement                0     0     0   154
# allegorical painting         0     2     3    13
# animal painting              3    40    16    11
# battle painting              0   136     0     0
# bird-and-flower painting     0     0     0     0
# capriccio                    0     0  2007     0
# caricature                   0    14     0   124
# cityscape                    0   158  2006     6
# cloudscape                   0     0     0    24
# design                       0   157    27   290
# figurative                   0    64     0    52
# flower painting              0     0     0     0
# genre painting               3   158    40     2
# graffiti                  2637     0     0     0
# history painting             0     7    87    33
# illustration                 0    44    22   340
# installation                 0    67    26     0
# interior                     0    36     0     0
# landscape                    0    52    48     4
# literary painting            0     1    13     0
# marina                       0    58    40     0
# miniature                    0     0     0  1691
# mythological painting        0    22     0     0
# nude painting                0    99     0     0
# nude painting (nu)           0   124     0     0
# panorama                     0     0     0     0
# pastorale                    0     0     0     0
# photo                        0     0     0     0
# portrait                     0   105     2     8
# poster                       0   208     0   478
# quadratura                   0     0     0     0
# religious painting           0    38     7     0
# sculpture                    0    26   115     0
# self-portrait                0    39     0     4
# sketch and study             2   112    52   251
# still life                   0   165     0     3
# symbolic painting            0    52     0     6
# tessellation                 0     0     0     0
# vanitas                      0     0     0     0
# veduta                       0     0  7475     0
# wildlife painting            0    71     0     0
# yakusha-e                    0  5872     0     0
#
# [44 rows x 44 columns]

# %% [markdown]
# ## 군집모형 성능평가

# %%
VGG_vectors = np.load(os.path.join(filepath,'VGG_vectors.npy'))
painting = pd.read_csv(os.path.join(filepath,'painting.csv'))

X = VGG_vectors
y = painting['genre']

# 라벨인코딩
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
len(le.classes_)
# Out:
# 44

# %%
model = KMeans(n_clusters=len(le.classes_), n_init=10, random_state=1)
model.fit(X)
# Out:
# KMeans(n_clusters=44, n_init=10, random_state=1)

# %%
pred = model.predict(X)
all(pred == model.labels_)
# Out:
# True

# %%
# 예측된 클러스터 라벨
pred = model.labels_

# 각 클러스터에서 가장 많이 등장하는 실제 라벨 찾기
mapping = {}
for cluster in range(len(le.classes_)):
    mask = (pred == cluster)
    if np.any(mask):  # 해당 클러스터에 속한 샘플이 존재하는 경우만 실행
        most_common_label = np.bincount(y_encoded[mask]).argmax()
        mapping[cluster] = most_common_label

# 클러스터 인덱스를 실제 라벨과 매핑
adjusted_pred = np.vectorize(mapping.get)(pred)

# 교차표 생성
cross_tab = pd.crosstab(y_encoded, adjusted_pred, rownames=['실제값'], colnames=['예측값'])

# 결과 출력
cross_tab
# Out:
# 예측값    1     9    13    14   17    20    30    33   36   37
# 실제값
# 0       0     2    0     5    0     1     2     2    0    1
# 1    3101    78   22   590  126   512   447   187  174   27
# 2       9     4    0     9    6     1    14     5    4    0
# 3      28    11    9   132   18    82   165   142    7   10
# 4      76    13    6   249   25   197   213    91   31    7
# 5       9     8    1    47   15    94    29    58    6    1
# 6       2     0    1     4    9     2     2     1    5    0
# col_0                     genre painting  illustration  landscape  portrait  \
# genre
# Canadian                               5             0          1         2
# abstract                             590           126        512       447
# advertisement                          9             6          1        14
# allegorical painting                 132            18         82       165
# animal painting                      249            25        197       213
# battle painting                       47            15         94        29
# bird-and-flower painting               4             9          2         2
# capriccio                              7             0         11         4
# caricature                            26            99         22        45
# cityscape                            747            56       1158       116
# cloudscape                             8             1         88         8
# design                               260            73         61       297
# figurative                           206            48         73       182
# flower painting                      156            14        264        94
# genre painting                      3737           281       2464      2240
# graffiti                               2             0          0         0
# history painting                     219             9        125        84
# illustration                         272           397        245       263
# installation                          24             1         13        29
# interior                             243             6         24        45
# landscape                           1042           191       9423       419
# literary painting                    114            12         73        80
# marina                                86             7        807        67
# miniature                              0             0          0         0
# mythological painting                329            30        227       344
# nude painting                        484            64        145       832
# nude painting (nu)                    25             4          7        23
# panorama                               1             0          8         1
# pastorale                              5             1         31        14
# photo                                 23             7         30        23
# portrait                            1844           268        656      9412
# poster                                34            50          7        62
# quadratura                             2             0          0         5
# religious painting                  1711           212        700      1824
# sculpture                             61             1         10       208
# self-portrait                        135            38         44       766
# sketch and study                     279            82        815       935
# still life                           616            44        170       650
# symbolic painting                    193            43        125       160
# tessellation                           0             2          0         0
# vanitas                                5             3          0        12
# veduta                                 2             0         30         3
# wildlife painting                     44             1         34        25
# yakusha-e                              2             7          0         4
#
# col_0                     religious painting  sketch and study  still life
# genre
# Canadian                                   2                 0           1
# abstract                                 187               174          27
# advertisement                              5                 4           0
# allegorical painting                     142                 7          10
# animal painting                           91                31           7
# battle painting                           58                 6           1
# bird-and-flower painting                   1                 5           0
# capriccio                                  3                 0           0
# caricature                                19                21           0
# cityscape                                147                40           2
# cloudscape                                13                 1           0
# design                                   214                96           6
# figurative                                65                82          10
# flower painting                           52                15          42
# genre painting                           866               172         129
# graffiti                                   1                 0           0
# history painting                         124                 1           0
# illustration                             377               130           5
# installation                               1                 5           1
# interior                                  62                 5           5
# landscape                                508                67           9
# literary painting                         88                 7           4
# marina                                    28                13           2
# miniature                                  2                 5           0
# mythological painting                    340                21          15
# nude painting                            136                83          21
# nude painting (nu)                         4                 0           0
# panorama                                   0                 0           0
# pastorale                                 16                 0           0
# photo                                      4                 0           1
# portrait                                 788               164         361
# poster                                    29                31           2
# quadratura                                 9                 0           0
# religious painting                      1693                44         136
# sculpture                                 37                12           3
# self-portrait                             79                35          22
# sketch and study                         422               797           4
# still life                               187                32         386
# symbolic painting                         78                11          16
# tessellation                               1                 0           0
# vanitas                                    2                 0           2
# veduta                                     3                 0           0
# wildlife painting                          9                 0           0
# yakusha-e                                  1                 3           0

# %% [markdown]
# ## 조정된 rand지수 외 성능평가 기준 함수

# %%
adjusted_rand_score(labels_true=y, labels_pred=pred_str)
# Out:
# 0.17784512628955776

# %%
adjusted_rand_score(labels_true=y_encoded, labels_pred=pred)
# Out:
# 0.06599707465394923

# %%
homogeneity_score(y, pred_str)
# Out:
# 0.15728402312823125

# %%
completeness_score(y, pred_str)
# Out:
# 0.21855092825783656

# %%
v_measure_score(y, pred_str)
# Out:
# 0.18292374952371843

# %%
mutual_info_score(y, pred_str)
# Out:
# 0.423435287293873

# %% [markdown]
# # 앙상블모형

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((440255, 512), (440255,), (188681, 512), (188681,))

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.fit_transform(y_test)

# %%
def model_measure(model, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test):
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    accuracy  = model.score(X_test, y_test)
    precision = precision_score(y_test, pred, average="macro")
    recall    = recall_score(y_test, pred, average="macro")
    f1score  = f1_score(y_test, pred, average="macro")
    return '정확도:{:.3f}, 정밀도:{:.3f}, 재현율:{:.3f}, f1_score:{:.3f}'.format(accuracy, precision, recall, f1score)

# %%
# LabelEncoder 객체 저장
joblib.dump(le, os.path.join(filepath,'genre_label.pkl'))

# %% [markdown]
# ## 의사결정 방식

# %% [markdown]
# ### 배깅 방식

# %%
rf = RandomForestClassifier(n_estimators=100,         # 의사결정나무 100개
                            max_features=len(set(y)),
                            random_state=42).fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.9587557835712128

# %%
rf_model = model_measure(RandomForestClassifier())
rf_model
# Out:
# '정확도:0.958, 정밀도:0.956, 재현율:0.958, f1_score:0.956'

# %% [markdown]
# ### 부스팅 방식

# %%
xgb = model_measure(XGBClassifier())
xgb
# Out:
# '정확도:0.942, 정밀도:0.941, 재현율:0.942, f1_score:0.941'

# %%
lgb = model_measure(LGBMClassifier(force_col_wise=True))
lgb
# Out:
# [LightGBM] [Info] Total Bins 130560
# [LightGBM] [Info] Number of data points in the train set: 440255, number of used features: 512
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784269
# [LightGBM] [Info] Start training from score -3.784269
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784269
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784269
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784269
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784269
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784269
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784269
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784269
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Info] Start training from score -3.784169
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# '정확도:0.921, 정밀도:0.920, 재현율:0.921, f1_score:0.920'

# %% [markdown]
# ### 투표를 이용한 앙상블

# %%
rf_model = RandomForestClassifier(n_estimators=100, # 의사결정나무 100개
                                  max_features=2, # 2개의 특징으로 나눔
                                  random_state=42)
xgb_model = XGBClassifier(max_depth=10,          # 트리의 최대 깊이
                          n_estimators=100,      # 트리 갯수
                          learning_rate=0.01,    # 학습률
                          eval_metric='logloss') # 평가지표(이진분류)
lgb_model = LGBMClassifier(force_col_wise=True, verbose=-1)

print(model_measure(rf_model))
print(model_measure(xgb_model))
print(model_measure(lgb_model))
# Out:
# 정확도:0.954, 정밀도:0.951, 재현율:0.954, f1_score:0.951
# 정확도:0.900, 정밀도:0.896, 재현율:0.900, f1_score:0.897
# 정확도:0.921, 정밀도:0.920, 재현율:0.921, f1_score:0.920

# %%
# 경량화된 랜덤포레스트 모델
rf_model = RandomForestClassifier(
    n_estimators=50,      # 트리 개수 줄이기
    max_depth=5,          # 트리 깊이 제한
    max_features='sqrt',  # 최적의 특징 개수 자동 선택
    random_state=42)

# 경량화된 XGBoost 모델
xgb_model = XGBClassifier(
    max_depth=4,          # 트리 깊이 제한
    n_estimators=50,      # 트리 개수 줄이기
    learning_rate=0.1,    # 학습 속도 증가
    subsample=0.8,        # 데이터 일부 샘플링
    colsample_bytree=0.8, # 일부 특성만 사용
    tree_method='hist',   # 히스토그램 기반 트리 (메모리 절약)
    eval_metric='logloss',
    random_state=42)

# 경량화된 LightGBM 모델
lgb_model = LGBMClassifier(
    n_estimators=50,      # 트리 개수 줄이기
    max_depth=4,          # 트리 깊이 제한
    num_leaves=16,        # 리프 개수 줄이기
    subsample=0.8,        # 데이터 일부 샘플링
    colsample_bytree=0.8,  # 일부 특성만 사용
    verbose=-1,           # 불필요한 출력 제거
    random_state=42)

print(model_measure(rf_model))
print(model_measure(xgb_model))
print(model_measure(lgb_model))
# Out:
# 정확도:0.432, 정밀도:0.440, 재현율:0.432, f1_score:0.342
# 정확도:0.758, 정밀도:0.749, 재현율:0.758, f1_score:0.749
# 정확도:0.811, 정밀도:0.804, 재현율:0.811, f1_score:0.806

# %%
# voting 알고리즘 - hard 방식
voting_model_hard = VotingClassifier(estimators=[('rfm', rf_model),
                                                 ('xgb', xgb_model),
                                                 ('lgb', lgb_model)],
                                     voting='hard') # voting='hard' 기본값

voting_model_hard.fit(X_sampled, y_sampled)
# Out:
# VotingClassifier(estimators=[('rfm',
#                               RandomForestClassifier(max_depth=5,
#                                                      n_estimators=50,
#                                                      random_state=42)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.8, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric='logloss',
#                                             feature_types=None, gamma=Non...
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=4,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=50, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             objective='multi:softprob', ...)),
#                              ('lgb',
#                               LGBMClassifier(colsample_bytree=0.8, max_depth=4,
#                                              n_estimators=50, num_leaves=16,
#                                              random_state=42, subsample=0.8,
#                                              verbose=-1))])

# %%
voting_model_hard.predict(X_test[0].reshape(1, -1))
# Out:
# array(['landscape'], dtype=object)

# %%
# voting 알고리즘 - soft 방식
voting_model_soft = VotingClassifier(estimators=[('rfm', rf_model),
                                                 ('xgb', xgb_model),
                                                 ('lgb', lgb_model)],
                                     voting='soft') # voting='hard' 기본값

voting_model_soft.fit(X_sampled, y_sampled)
# Out:
# VotingClassifier(estimators=[('rfm',
#                               RandomForestClassifier(max_depth=5,
#                                                      n_estimators=50,
#                                                      random_state=42)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.8, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric='logloss',
#                                             feature_types=None, gamma=Non...
#                                             max_delta_step=None, max_depth=4,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=50, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             objective='multi:softprob', ...)),
#                              ('lgb',
#                               LGBMClassifier(colsample_bytree=0.8, max_depth=4,
#                                              n_estimators=50, num_leaves=16,
#                                              random_state=42, subsample=0.8,
#                                              verbose=-1))],
#                  voting='soft')

# %%
voting_model_soft.predict(X_test[0].reshape(1, -1))
# Out:
# array(['landscape'], dtype=object)

# %%
y_test[0]
# Out:
# 20

# %%
y_inverse_test = le.inverse_transform(y_test)
y_inverse_test[0]
# Out:
# 'landscape'

# %%
model_measure(voting_model_hard)
# Out:
# '정확도:0.770, 정밀도:0.762, 재현율:0.770, f1_score:0.758'

# %%
model_measure(voting_model_soft)
# Out:
# '정확도:0.801, 정밀도:0.794, 재현율:0.801, f1_score:0.795'

# %%
# voting_model_hard의 개별 모델들 딕셔너리 형태로 반환
voting_model_hard.named_estimators_
# Out:
# {'rfm': RandomForestClassifier(max_depth=5, n_estimators=50, random_state=42),
#  'xgb': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric='logloss',
#                feature_types=None, gamma=None, grow_policy=None,
#                importance_type=None, interaction_constraints=None,
#                learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#                max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#                max_leaves=None, min_child_weight=None, missing=nan,
#                monotone_constraints=None, multi_strategy=None, n_estimators=50,
#                n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...),
#  'lgb': LGBMClassifier(colsample_bytree=0.8, max_depth=4, n_estimators=50,
#                 num_leaves=16, random_state=42, subsample=0.8, verbose=-1)}

# %%
# voting_model_soft의 개별 모델들 딕셔너리 형태로 반환
voting_model_soft.named_estimators_
# Out:
# {'rfm': RandomForestClassifier(max_depth=5, n_estimators=50, random_state=42),
#  'xgb': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric='logloss',
#                feature_types=None, gamma=None, grow_policy=None,
#                importance_type=None, interaction_constraints=None,
#                learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#                max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#                max_leaves=None, min_child_weight=None, missing=nan,
#                monotone_constraints=None, multi_strategy=None, n_estimators=50,
#                n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...),
#  'lgb': LGBMClassifier(colsample_bytree=0.8, max_depth=4, n_estimators=50,
#                 num_leaves=16, random_state=42, subsample=0.8, verbose=-1)}

# %%
# voting_model_hard.named_estimators_ 단일모델로 개별모델 access 가능
print(model_measure(voting_model_hard.named_estimators_['rfm']))  
print(model_measure(voting_model_hard.named_estimators_['xgb']))
print(model_measure(voting_model_hard.named_estimators_['lgb']))
# Out:
# 정확도:0.432, 정밀도:0.440, 재현율:0.432, f1_score:0.342
# 정확도:0.758, 정밀도:0.749, 재현율:0.758, f1_score:0.749
# 정확도:0.811, 정밀도:0.804, 재현율:0.811, f1_score:0.806

# %%
# voting_model_soft.named_estimators_ 단일모델로 개별모델 access 가능
print(model_measure(voting_model_soft.named_estimators_['rfm']))  
print(model_measure(voting_model_soft.named_estimators_['xgb']))
print(model_measure(voting_model_soft.named_estimators_['lgb']))
# Out:
# 정확도:0.432, 정밀도:0.440, 재현율:0.432, f1_score:0.342
# 정확도:0.758, 정밀도:0.749, 재현율:0.758, f1_score:0.749
# 정확도:0.811, 정밀도:0.804, 재현율:0.811, f1_score:0.806

# %%
# 모델 내의 모든 파라미터(하이퍼파라미터)
voting_model_hard.get_params()
# Out:
# {'estimators': [('rfm',
#    RandomForestClassifier(max_depth=5, n_estimators=50, random_state=42)),
#   ('xgb',
#    XGBClassifier(base_score=None, booster=None, callbacks=None,
#                  colsample_bylevel=None, colsample_bynode=None,
#                  colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#                  enable_categorical=False, eval_metric='logloss',
#                  feature_types=None, gamma=None, grow_policy=None,
#                  importance_type=None, interaction_constraints=None,
#                  learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#                  max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#                  max_leaves=None, min_child_weight=None, missing=nan,
#                  monotone_constraints=None, multi_strategy=None, n_estimators=50,
#                  n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...)),
#   ('lgb',
#    LGBMClassifier(colsample_bytree=0.8, max_depth=4, n_estimators=50,
#                   num_leaves=16, random_state=42, subsample=0.8, verbose=-1))],
#  'flatten_transform': True,
#  'n_jobs': None,
#  'verbose': False,
#  'voting': 'hard',
#  'weights': None,
#  'rfm': RandomForestClassifier(max_depth=5, n_estimators=50, random_state=42),
#  'xgb': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric='logloss',
#                feature_types=None, gamma=None, grow_policy=None,
#                importance_type=None, interaction_constraints=None,
#                learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#                max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#                max_leaves=None, min_child_weight=None, missing=nan,
#                monotone_constraints=None, multi_strategy=None, n_estimators=50,
#                n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...),
#  'lgb': LGBMClassifier(colsample_bytree=0.8, max_depth=4, n_estimators=50,
#                 num_leaves=16, random_state=42, subsample=0.8, verbose=-1),
#  'rfm__bootstrap': True,
#  'rfm__ccp_alpha': 0.0,
#  'rfm__class_weight': None,
#  'rfm__criterion': 'gini',
#  'rfm__max_depth': 5,
#  'rfm__max_features': 'sqrt',
#  'rfm__max_leaf_nodes': None,
#  'rfm__max_samples': None,
#  'rfm__min_impurity_decrease': 0.0,
#  'rfm__min_samples_leaf': 1,
#  'rfm__min_samples_split': 2,
#  'rfm__min_weight_fraction_leaf': 0.0,
#  'rfm__n_estimators': 50,
#  'rfm__n_jobs': None,
#  'rfm__oob_score': False,
#  'rfm__random_state': 42,
#  'rfm__verbose': 0,
#  'rfm__warm_start': False,
#  'xgb__objective': 'multi:softprob',
#  'xgb__base_score': None,
#  'xgb__booster': None,
#  'xgb__callbacks': None,
#  'xgb__colsample_bylevel': None,
#  'xgb__colsample_bynode': None,
#  'xgb__colsample_bytree': 0.8,
#  'xgb__device': None,
#  'xgb__early_stopping_rounds': None,
#  'xgb__enable_categorical': False,
#  'xgb__eval_metric': 'logloss',
#  'xgb__feature_types': None,
#  'xgb__gamma': None,
#  'xgb__grow_policy': None,
#  'xgb__importance_type': None,
#  'xgb__interaction_constraints': None,
#  'xgb__learning_rate': 0.1,
#  'xgb__max_bin': None,
#  'xgb__max_cat_threshold': None,
#  'xgb__max_cat_to_onehot': None,
#  'xgb__max_delta_step': None,
#  'xgb__max_depth': 4,
#  'xgb__max_leaves': None,
#  'xgb__min_child_weight': None,
#  'xgb__missing': nan,
#  'xgb__monotone_constraints': None,
#  'xgb__multi_strategy': None,
#  'xgb__n_estimators': 50,
#  'xgb__n_jobs': None,
#  'xgb__num_parallel_tree': None,
#  'xgb__random_state': 42,
#  'xgb__reg_alpha': None,
#  'xgb__reg_lambda': None,
#  'xgb__sampling_method': None,
#  'xgb__scale_pos_weight': None,
#  'xgb__subsample': 0.8,
#  'xgb__tree_method': 'hist',
#  'xgb__validate_parameters': None,
#  'xgb__verbosity': None,
#  'lgb__boosting_type': 'gbdt',
#  'lgb__class_weight': None,
#  'lgb__colsample_bytree': 0.8,
#  'lgb__importance_type': 'split',
#  'lgb__learning_rate': 0.1,
#  'lgb__max_depth': 4,
#  'lgb__min_child_samples': 20,
#  'lgb__min_child_weight': 0.001,
#  'lgb__min_split_gain': 0.0,
#  'lgb__n_estimators': 50,
#  'lgb__n_jobs': None,
#  'lgb__num_leaves': 16,
#  'lgb__objective': None,
#  'lgb__random_state': 42,
#  'lgb__reg_alpha': 0.0,
#  'lgb__reg_lambda': 0.0,
#  'lgb__subsample': 0.8,
#  'lgb__subsample_for_bin': 200000,
#  'lgb__subsample_freq': 0,
#  'lgb__verbose': -1}

# %%
# 모델 내의 모든 파라미터(하이퍼파라미터)
voting_model_soft.get_params()
# Out:
# {'estimators': [('rfm',
#    RandomForestClassifier(max_depth=5, n_estimators=50, random_state=42)),
#   ('xgb',
#    XGBClassifier(base_score=None, booster=None, callbacks=None,
#                  colsample_bylevel=None, colsample_bynode=None,
#                  colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#                  enable_categorical=False, eval_metric='logloss',
#                  feature_types=None, gamma=None, grow_policy=None,
#                  importance_type=None, interaction_constraints=None,
#                  learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#                  max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#                  max_leaves=None, min_child_weight=None, missing=nan,
#                  monotone_constraints=None, multi_strategy=None, n_estimators=50,
#                  n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...)),
#   ('lgb',
#    LGBMClassifier(colsample_bytree=0.8, max_depth=4, n_estimators=50,
#                   num_leaves=16, random_state=42, subsample=0.8, verbose=-1))],
#  'flatten_transform': True,
#  'n_jobs': None,
#  'verbose': False,
#  'voting': 'soft',
#  'weights': None,
#  'rfm': RandomForestClassifier(max_depth=5, n_estimators=50, random_state=42),
#  'xgb': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric='logloss',
#                feature_types=None, gamma=None, grow_policy=None,
#                importance_type=None, interaction_constraints=None,
#                learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#                max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#                max_leaves=None, min_child_weight=None, missing=nan,
#                monotone_constraints=None, multi_strategy=None, n_estimators=50,
#                n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...),
#  'lgb': LGBMClassifier(colsample_bytree=0.8, max_depth=4, n_estimators=50,
#                 num_leaves=16, random_state=42, subsample=0.8, verbose=-1),
#  'rfm__bootstrap': True,
#  'rfm__ccp_alpha': 0.0,
#  'rfm__class_weight': None,
#  'rfm__criterion': 'gini',
#  'rfm__max_depth': 5,
#  'rfm__max_features': 'sqrt',
#  'rfm__max_leaf_nodes': None,
#  'rfm__max_samples': None,
#  'rfm__min_impurity_decrease': 0.0,
#  'rfm__min_samples_leaf': 1,
#  'rfm__min_samples_split': 2,
#  'rfm__min_weight_fraction_leaf': 0.0,
#  'rfm__n_estimators': 50,
#  'rfm__n_jobs': None,
#  'rfm__oob_score': False,
#  'rfm__random_state': 42,
#  'rfm__verbose': 0,
#  'rfm__warm_start': False,
#  'xgb__objective': 'multi:softprob',
#  'xgb__base_score': None,
#  'xgb__booster': None,
#  'xgb__callbacks': None,
#  'xgb__colsample_bylevel': None,
#  'xgb__colsample_bynode': None,
#  'xgb__colsample_bytree': 0.8,
#  'xgb__device': None,
#  'xgb__early_stopping_rounds': None,
#  'xgb__enable_categorical': False,
#  'xgb__eval_metric': 'logloss',
#  'xgb__feature_types': None,
#  'xgb__gamma': None,
#  'xgb__grow_policy': None,
#  'xgb__importance_type': None,
#  'xgb__interaction_constraints': None,
#  'xgb__learning_rate': 0.1,
#  'xgb__max_bin': None,
#  'xgb__max_cat_threshold': None,
#  'xgb__max_cat_to_onehot': None,
#  'xgb__max_delta_step': None,
#  'xgb__max_depth': 4,
#  'xgb__max_leaves': None,
#  'xgb__min_child_weight': None,
#  'xgb__missing': nan,
#  'xgb__monotone_constraints': None,
#  'xgb__multi_strategy': None,
#  'xgb__n_estimators': 50,
#  'xgb__n_jobs': None,
#  'xgb__num_parallel_tree': None,
#  'xgb__random_state': 42,
#  'xgb__reg_alpha': None,
#  'xgb__reg_lambda': None,
#  'xgb__sampling_method': None,
#  'xgb__scale_pos_weight': None,
#  'xgb__subsample': 0.8,
#  'xgb__tree_method': 'hist',
#  'xgb__validate_parameters': None,
#  'xgb__verbosity': None,
#  'lgb__boosting_type': 'gbdt',
#  'lgb__class_weight': None,
#  'lgb__colsample_bytree': 0.8,
#  'lgb__importance_type': 'split',
#  'lgb__learning_rate': 0.1,
#  'lgb__max_depth': 4,
#  'lgb__min_child_samples': 20,
#  'lgb__min_child_weight': 0.001,
#  'lgb__min_split_gain': 0.0,
#  'lgb__n_estimators': 50,
#  'lgb__n_jobs': None,
#  'lgb__num_leaves': 16,
#  'lgb__objective': None,
#  'lgb__random_state': 42,
#  'lgb__reg_alpha': 0.0,
#  'lgb__reg_lambda': 0.0,
#  'lgb__subsample': 0.8,
#  'lgb__subsample_for_bin': 200000,
#  'lgb__subsample_freq': 0,
#  'lgb__verbose': -1}

# %% [markdown]
# # 사용할 머신러닝 학습 모형 저장

# %%
# 모델저장하기 
filename = 'rf.joblib'
file_path = os.path.join(filepath,filename)
print(joblib.dump(rf, file_path))
# Out:
# ['../team_project/data/rf.joblib']

# %%
# 모델 load
jobilb_rf = joblib.load(os.path.join(file_path))
model_measure(jobilb_rf)
# Out:
# '정확도:0.959, 정밀도:0.956, 재현율:0.959, f1_score:0.957'
