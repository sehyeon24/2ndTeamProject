# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:80% !important;}
div.prompt {min-width:70px;}
div#toc-header{margin-top:150px;}
span.toc-item-num{display:none;}
div.CodeMirror {font-family:Consolas}
div.input {font-family:Consolas}
</style>
"""))
# Out:
# <style>
# div.container{width:80% !important;}
# div.prompt {min-width:70px;}
# div#toc-header{margin-top:150px;}
# span.toc-item-num{display:none;}
# div.CodeMirror {font-family:Consolas}
# div.input {font-family:Consolas}
# </style>

# %%
import pandas as pd
import os
filepath=r'D:\ai\Downloads\Data\paintings\data'

# %%
df = pd.read_csv(os.path.join(filepath,'painting.csv'))  # CSV 레이블 데이터
df
# Out:
#                                                     file  \
# 0      Realism/vincent-van-gogh_pine-trees-in-the-fen...
# 1      Baroque/rembrandt_the-angel-appearing-to-the-s...
# 2      Post_Impressionism/paul-cezanne_portrait-of-th...
# 3      Impressionism/pierre-auguste-renoir_young-girl...
# 4           Romanticism/ivan-aivazovsky_morning-1851.jpg
# ...                                                  ...
# 80153  Naive_Art_Primitivism/mary-fedden_butterflies-...
# 80154  Naive_Art_Primitivism/arman-manookian_watercol...
# 80155  Naive_Art_Primitivism/andre-bauchant_exotic-fl...
# 80156  Naive_Art_Primitivism/ivan-generalic_cows-in-a...
# 80157  Naive_Art_Primitivism/natalia-goncharova_sheep...
#
#                                            title                 artist  \
# 0                     pine-trees-in-the-fen-1884       vincent-van-gogh
# 1      the-angel-appearing-to-the-shepherds-1634              rembrandt
# ...

# %%
# artist 열에서 중복 제거하고 고유한 값만 추출
unique_artists = df['genre'].drop_duplicates()

# 결과 출력
print(unique_artists)
# Out:
# 0                       landscape
# 1              religious painting
# 2                        portrait
# 3                  genre painting
# 4                          marina
# 6                 flower painting
# 15                     still life
# 16               sketch and study
# 17                   illustration
# 22                      cityscape
# 29                  nude painting
# 33                  self-portrait
# 37                         design
# 91                       interior
# 103               animal painting
# 111         mythological painting
# 160              history painting
# 173             symbolic painting
# 187                    cloudscape
# 191               battle painting
# 304                    figurative
# 475             literary painting
# 540                      panorama
# 564          allegorical painting
# 718                 advertisement
# 725                    caricature
# 843                     sculpture
# ...

# %%
unique_artists.to_csv(os.path.join(filepath,'genre.csv'), index=False)
